# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
from sklearn.preprocessing import LabelEncoder
import category_encoders as ce
from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier,AdaBoostClassifier
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn import set_config
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV,RandomizedSearchCV,ParameterGrid
import optuna.integration.lightgbm as lgb
from sklearn.model_selection import cross_val_score
import optuna
from sklearn.metrics import accuracy_score,f1_score
from sklearn.metrics import roc_auc_score
import 
# %matplotlib inline

# %%
import featuretools as ft

# matplotlit and seaborn for visualizations
import matplotlib.pyplot as plt
plt.rcParams['font.size'] = 22
import seaborn as sns

# Suppress warnings from pandas
import warnings
warnings.filterwarnings('ignore')

# %%
app_train = pd.read_csv('application_train.csv').sort_values('SK_ID_CURR').reset_index(drop = True).loc[:1000, :]
app_test = pd.read_csv('application_test.csv').sort_values('SK_ID_CURR').reset_index(drop = True).loc[:1000, :]
bureau_balance = pd.read_csv('bureau_balance.csv').sort_values('SK_ID_BUREAU').reset_index(drop = True).loc[:1000, :]
bureau = pd.read_csv('bureau.csv').sort_values(['SK_ID_CURR', 'SK_ID_BUREAU']).reset_index(drop = True).loc[:1000, :]
credit = pd.read_csv('credit_card_balance.csv').sort_values(['SK_ID_CURR', 'SK_ID_PREV']).reset_index(drop = True).loc[:1000, :]
#HomeCredit_columns_description = pd.read_csv('HomeCredit_columns_description.csv')
installments =  pd.read_csv('installments_payments.csv').sort_values(['SK_ID_CURR', 'SK_ID_PREV']).reset_index(drop = True).loc[:1000, :]
cash = pd.read_csv('POS_CASH_balance.csv').sort_values(['SK_ID_CURR', 'SK_ID_PREV']).reset_index(drop = True).loc[:1000, :]
previous = pd.read_csv('previous_application.csv').sort_values(['SK_ID_CURR', 'SK_ID_PREV']).reset_index(drop = True).loc[:1000, :]

# %%
# Add identifying column
app_train['set'] = 'train'
app_test['set'] = 'test'
app_test["TARGET"] = np.nan

# Append the dataframes
app = app_train.append(app_test, ignore_index = True)

# %%
#Entity set with id applications
es = ft.EntitySet(id = 'clients')

# %%
#Entitiy with a unique index
es = es.add_dataframe(dataframe_name = 'app', dataframe = app, index = 'SK_ID_CURR')
es = es.add_dataframe(dataframe_name = 'bureau', dataframe = bureau, index = 'SK_ID_BUREAU')
es = es.add_dataframe(dataframe_name = 'previous', dataframe = previous, index = 'SK_ID_PREV')

#Entities that do not have a unique index
es = es.add_dataframe(dataframe_name = 'bureau_balance', dataframe = bureau_balance,make_index = True, index = 'bureaubalance_index')
es = es.add_dataframe(dataframe_name = 'cash', dataframe = cash,make_index = True, index = 'cash_index')
es = es.add_dataframe(dataframe_name = 'installments', dataframe = installments,make_index = True, index = 'installments_index')
es = es.add_dataframe(dataframe_name = 'credit', dataframe = credit, make_index = True, index = 'credit_index')

# %%
print('Parent: app, Parent Variable: SK_ID_CURR\n\n', app.iloc[:, 111:115].head())
print('\nChild: bureau, Child Variable: SK_ID_CURR\n\n', bureau.iloc[10:30, :4].head())
# Out:
# Parent: app, Parent Variable: SK_ID_CURR
#
#          FLAG_DOCUMENT_17  FLAG_DOCUMENT_18  FLAG_DOCUMENT_19  FLAG_DOCUMENT_20
# 100002                 0                 0                 0                 0
# 100003                 0                 0                 0                 0
# 100004                 0                 0                 0                 0
# 100006                 0                 0                 0                 0
# 100007                 0                 0                 0                 0
#
# Child: bureau, Child Variable: SK_ID_CURR
#
#           SK_ID_CURR  SK_ID_BUREAU CREDIT_ACTIVE CREDIT_CURRENCY
# 6158905      100002       6158905        Closed      currency 1
# 6158906      100002       6158906        Closed      currency 1
# 6158907      100002       6158907        Closed      currency 1
# 6158908      100002       6158908        Closed      currency 1
# 6158909      100002       6158909        Active      currency 1

# %%
#Relationship between app and breau
r_app_bureau = es.add_relationship('app','SK_ID_CURR','bureau','SK_ID_CURR')

#Relationship between bureau and bureau balance
r_bureau_balance = es.add_relationship('bureau','SK_ID_BUREAU','bureau_balance','SK_ID_BUREAU')

# Relationship between current app and previous apps
r_app_previous = es.add_relationship('app','SK_ID_CURR','previous','SK_ID_CURR')

# Relationships between previous apps and cash, installments, and credit
r_previous_cash = es.add_relationship('previous','SK_ID_PREV','cash','SK_ID_PREV')
r_previous_installments = es.add_relationship('previous','SK_ID_PREV','installments','SK_ID_PREV')
r_previous_credit = es.add_relationship('previous','SK_ID_PREV','credit','SK_ID_PREV')

# %%
# Add in the defined relationships
es = es.add_relationships([r_app_bureau, r_bureau_balance, r_app_previous,
                           r_previous_cash, r_previous_installments, r_previous_credit])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-33-506845983376> in <module>
#       1 # Add in the defined relationships
# ----> 2 es = es.add_relationships([r_app_bureau, r_bureau_balance, r_app_previous,
#       3                            r_previous_cash, r_previous_installments, r_previous_credit])
#
# /opt/anaconda3/lib/python3.8/site-packages/featuretools/entityset/entityset.py in add_relationships(self, relationships)
#     294                 self.add_relationship(relationship=rel)
#     295             else:
# --> 296                 self.add_relationship(*rel)
#     297         return self
#     298
#
# /opt/anaconda3/lib/python3.8/site-packages/featuretools/entityset/entityset.py in __getitem__(self, dataframe_name)
#     155             return self.dataframe_dict[dataframe_name]
#     156         name = self.id or "entity set"
# --> 157         raise KeyError('DataFrame %s does not exist in %s' % (dataframe_name, name))
#     158
#     159     def __deepcopy__(self, memo):
#
# KeyError: 'DataFrame 0 does not exist in clients'

# %%
es
# Out:
# Entityset: clients
#   DataFrames:
#     app [Rows: 2002, Columns: 123]
#     bureau [Rows: 1001, Columns: 17]
#     previous [Rows: 1001, Columns: 37]
#     bureau_balance [Rows: 1001, Columns: 4]
#     cash [Rows: 1001, Columns: 9]
#     installments [Rows: 1001, Columns: 9]
#     credit [Rows: 1001, Columns: 24]
#   Relationships:
#     bureau.SK_ID_CURR -> app.SK_ID_CURR
#     bureau_balance.SK_ID_BUREAU -> bureau.SK_ID_BUREAU
#     previous.SK_ID_CURR -> app.SK_ID_CURR
#     cash.SK_ID_PREV -> previous.SK_ID_PREV
#     installments.SK_ID_PREV -> previous.SK_ID_PREV
#     credit.SK_ID_PREV -> previous.SK_ID_PREV

# %%
# List the primitives in a dataframe
primitives = ft.list_primitives()
pd.options.display.max_colwidth = 100
primitives[primitives['type'] == 'aggregation'].head(10)
# Out:
#                name         type  dask_compatible  koalas_compatible  \
# 0     n_most_common  aggregation            False              False
# 1               max  aggregation             True               True
# 2  time_since_first  aggregation            False              False
# 3               sum  aggregation             True               True
# 4              mode  aggregation            False              False
# 5               all  aggregation             True              False
# 6              last  aggregation            False              False
# 7      percent_true  aggregation             True              False
# 8           entropy  aggregation            False              False
# 9               std  aggregation             True               True
#
#                                                            description  \
# 0                             Determines the `n` most common elements.
# 1                 Calculates the highest value, ignoring `NaN` values.
# 2   Calculates the time elapsed since the first datetime (in seconds).
# 3                       Calculates the total addition, ignoring `NaN`.
# 4                         Determines the most commonly repeated value.
# 5                       Calculates if all values are 'True' in a list.
# 6                                 Determines the last value in a list.
# 7                             Determines the percent of `True` values.
# 8                      Calculates the entropy for a categorical column
# 9  Computes the dispersion relative to the mean value, ignoring `NaN`.
#
#                                                                                valid_inputs  \
# 0                                             <ColumnSchema (Semantic Tags = ['category'])>
# 1                                              <ColumnSchema (Semantic Tags = ['numeric'])>
# 2                 <ColumnSchema (Logical Type = Datetime) (Semantic Tags = ['time_index'])>
# 3                                              <ColumnSchema (Semantic Tags = ['numeric'])>
# 4                                             <ColumnSchema (Semantic Tags = ['category'])>
# 5  <ColumnSchema (Logical Type = BooleanNullable)>, <ColumnSchema (Logical Type = Boolean)>
# 6                                                                            <ColumnSchema>
# 7  <ColumnSchema (Logical Type = BooleanNullable)>, <ColumnSchema (Logical Type = Boolean)>
# 8                                             <ColumnSchema (Semantic Tags = ['category'])>
# 9                                              <ColumnSchema (Semantic Tags = ['numeric'])>
#
#   return_type
# 0        None
# 1        None
# 2        None
# 3        None
# 4        None
# 5        None
# 6        None
# 7        None
# 8        None
# 9        None

# %%
primitives[primitives['type'] == 'transform'].head(10)
# Out:
#                        name       type  dask_compatible  koalas_compatible  \
# 22       add_numeric_scalar  transform             True               True
# 23                 cum_mean  transform            False              False
# 24  email_address_to_domain  transform            False              False
# 25               percentile  transform            False              False
# 26               is_weekend  transform             True               True
# 27                  cum_sum  transform            False              False
# 28       less_than_equal_to  transform             True               True
# 29                       or  transform             True               True
# 30               url_to_tld  transform            False              False
# 31        modulo_by_feature  transform             True               True
#
#                                                                  description  \
# 22                                   Add a scalar to each value in the list.
# 23                                           Calculates the cumulative mean.
# 24                                         Determines the domain of an email
# 25                  Determines the percentile rank for each value in a list.
# 26                                  Determines if a date falls on a weekend.
# 27                                            Calculates the cumulative sum.
# 28  Determines if values in one list are less than or equal to another list.
# 29                                     Element-wise logical OR of two lists.
# 30                                 Determines the top level domain of a url.
# 31                Return the modulo of a scalar by each element in the list.
#
#                                                                                            valid_inputs  \
# 22                                                         <ColumnSchema (Semantic Tags = ['numeric'])>
# 23                                                         <ColumnSchema (Semantic Tags = ['numeric'])>
# 24                                                         <ColumnSchema (Logical Type = EmailAddress)>
# 25                                                         <ColumnSchema (Semantic Tags = ['numeric'])>
# 26                                                             <ColumnSchema (Logical Type = Datetime)>
# 27                                                         <ColumnSchema (Semantic Tags = ['numeric'])>
# 28  <ColumnSchema (Logical Type = Datetime)>, <ColumnSchema (Semantic Tags = ['numeric'])>, <ColumnS...
# 29             <ColumnSchema (Logical Type = BooleanNullable)>, <ColumnSchema (Logical Type = Boolean)>
# 30                                                                  <ColumnSchema (Logical Type = URL)>
# 31                                                         <ColumnSchema (Semantic Tags = ['numeric'])>
#
#    return_type
# 22        None
# 23        None
# 24        None
# 25        None
# 26        None
# 27        None
# 28        None
# 29        None
# 30        None
# 31        None

# %%
# Default primitives from featuretools
default_agg_primitives =  ["sum", "std", "max", "skew", "min", "mean", "count", "percent_true", "num_unique", "mode"]
default_trans_primitives =  ["day", "year", "month", "weekday", "haversine"]

# DFS with specified primitives
feature_names = ft.dfs(entityset = es, target_dataframe_name='app',
                       trans_primitives = default_trans_primitives,
                       agg_primitives= default_agg_primitives, 
                       max_depth = 2, features_only=True)

print('%d Total Features' % len(feature_names))
# Out:
# 2213 Total Features

# %%
feature_matrix,feature_names = ft.dfs(entityset = es, target_dataframe_name = 'app',
                                       trans_primitives = default_trans_primitives,
                                       agg_primitives=default_agg_primitives, 
                                        max_depth = 2, features_only=False, verbose = True)

pd.options.display.max_columns = 1700
feature_matrix.head(10)
# Out:
# Built 2213 features
# Elapsed: 00:14 | Progress: 100%|██████████
#             TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# SK_ID_CURR
# 100002         1.0         Cash loans           M            N
# 100003         0.0         Cash loans           F            N
# 100004         0.0    Revolving loans           M            Y
# 100006         0.0         Cash loans           F            N
# 100007         0.0         Cash loans           M            N
# 100008         0.0         Cash loans           M            N
# 100009         0.0         Cash loans           F            Y
# 100010         0.0         Cash loans           M            Y
# 100011         0.0         Cash loans           F            N
# 100012         0.0    Revolving loans           M            N
#
#            FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  \
# SK_ID_CURR
# 100002                   Y             0          202500.0    406597.5
# 100003                   N             0          270000.0   1293502.5
# 100004                   Y             0           67500.0    135000.0
# 100006                   Y             0          135000.0    312682.5
# 100007                   Y             0          121500.0    513000.0
# 100008                   Y             0           99000.0    490495.5
# 100009                   Y             1          171000.0   1560726.0
# 100010                   Y             0          360000.0   1530000.0
# 100011                   Y             0          112500.0   1019610.0
# 100012                   Y             0          135000.0    405000.0
#
#             AMT_ANNUITY  AMT_GOODS_PRICE  NAME_TYPE_SUITE  \
# SK_ID_CURR
# 100002          24700.5         351000.0    Unaccompanied
# 100003          35698.5        1129500.0           Family
# 100004           6750.0         135000.0    Unaccompanied
# 100006          29686.5         297000.0    Unaccompanied
# 100007          21865.5         513000.0    Unaccompanied
# 100008          27517.5         454500.0  Spouse, partner
# 100009          41301.0        1395000.0    Unaccompanied
# 100010          42075.0        1530000.0    Unaccompanied
# 100011          33826.5         913500.0         Children
# 100012          20250.0         405000.0    Unaccompanied
#
#                 NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# SK_ID_CURR
# 100002                   Working  Secondary / secondary special
# 100003             State servant               Higher education
# 100004                   Working  Secondary / secondary special
# 100006                   Working  Secondary / secondary special
# 100007                   Working  Secondary / secondary special
# 100008             State servant  Secondary / secondary special
# 100009      Commercial associate               Higher education
# 100010             State servant               Higher education
# 100011                 Pensioner  Secondary / secondary special
# 100012                   Working  Secondary / secondary special
#
#               NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  \
# SK_ID_CURR
# 100002      Single / not married  House / apartment
# 100003                   Married  House / apartment
# 100004      Single / not married  House / apartment
# 100006            Civil marriage  House / apartment
# 100007      Single / not married  House / apartment
# 100008                   Married  House / apartment
# 100009                   Married  House / apartment
# 100010                   Married  House / apartment
# 100011                   Married  House / apartment
# 100012      Single / not married  House / apartment
#
#             REGION_POPULATION_RELATIVE  DAYS_BIRTH  DAYS_EMPLOYED  \
# SK_ID_CURR
# 100002                        0.018801       -9461           -637
# 100003                        0.003541      -16765          -1188
# 100004                        0.010032      -19046           -225
# 100006                        0.008019      -19005          -3039
# 100007                        0.028663      -19932          -3038
# 100008                        0.035792      -16941          -1588
# 100009                        0.035792      -13778          -3130
# 100010                        0.003122      -18850           -449
# 100011                        0.018634      -20099         365243
# 100012                        0.019689      -14469          -2019
#
#             DAYS_REGISTRATION  DAYS_ID_PUBLISH  OWN_CAR_AGE  FLAG_MOBIL  \
# SK_ID_CURR
# 100002                -3648.0            -2120          NaN           1
# 100003                -1186.0             -291          NaN           1
# 100004                -4260.0            -2531         26.0           1
# 100006                -9833.0            -2437          NaN           1
# 100007                -4311.0            -3458          NaN           1
# 100008                -4970.0             -477          NaN           1
# 100009                -1213.0             -619         17.0           1
# 100010                -4597.0            -2379          8.0           1
# 100011                -7427.0            -3514          NaN           1
# 100012               -14437.0            -3992          NaN           1
#
#             FLAG_EMP_PHONE  FLAG_WORK_PHONE  FLAG_CONT_MOBILE  FLAG_PHONE  \
# SK_ID_CURR
# 100002                   1                0                 1           1
# 100003                   1                0                 1           1
# 100004                   1                1                 1           1
# 100006                   1                0                 1           0
# 100007                   1                0                 1           0
# 100008                   1                1                 1           1
# 100009                   1                0                 1           1
# 100010                   1                1                 1           0
# 100011                   0                0                 1           0
# 100012                   1                0                 1           0
#
#             FLAG_EMAIL OCCUPATION_TYPE  CNT_FAM_MEMBERS  REGION_RATING_CLIENT  \
# SK_ID_CURR
# 100002               0        Laborers              1.0                     2
# 100003               0      Core staff              2.0                     1
# 100004               0        Laborers              1.0                     2
# 100006               0        Laborers              2.0                     2
# 100007               0      Core staff              1.0                     2
# 100008               0        Laborers              2.0                     2
# 100009               0     Accountants              3.0                     2
# 100010               0        Managers              2.0                     3
# 100011               0             NaN              2.0                     2
# 100012               0        Laborers              1.0                     2
#
#             REGION_RATING_CLIENT_W_CITY WEEKDAY_APPR_PROCESS_START  \
# SK_ID_CURR
# 100002                                2                  WEDNESDAY
# 100003                                1                     MONDAY
# 100004                                2                     MONDAY
# 100006                                2                  WEDNESDAY
# 100007                                2                   THURSDAY
# 100008                                2                  WEDNESDAY
# 100009                                2                     SUNDAY
# 100010                                3                     MONDAY
# 100011                                2                  WEDNESDAY
# 100012                                2                   THURSDAY
#
#             HOUR_APPR_PROCESS_START  REG_REGION_NOT_LIVE_REGION  \
# SK_ID_CURR
# 100002                           10                           0
# 100003                           11                           0
# 100004                            9                           0
# 100006                           17                           0
# 100007                           11                           0
# 100008                           16                           0
# 100009                           16                           0
# 100010                           16                           0
# 100011                           14                           0
# 100012                            8                           0
#
#             REG_REGION_NOT_WORK_REGION  LIVE_REGION_NOT_WORK_REGION  \
# SK_ID_CURR
# 100002                               0                            0
# 100003                               0                            0
# 100004                               0                            0
# 100006                               0                            0
# 100007                               0                            0
# 100008                               0                            0
# 100009                               0                            0
# 100010                               0                            0
# 100011                               0                            0
# 100012                               0                            0
#
#             REG_CITY_NOT_LIVE_CITY  REG_CITY_NOT_WORK_CITY  \
# SK_ID_CURR
# 100002                           0                       0
# 100003                           0                       0
# 100004                           0                       0
# 100006                           0                       0
# 100007                           0                       1
# 100008                           0                       0
# 100009                           0                       0
# 100010                           0                       1
# 100011                           0                       0
# 100012                           0                       0
#
#             LIVE_CITY_NOT_WORK_CITY       ORGANIZATION_TYPE  EXT_SOURCE_1  \
# SK_ID_CURR
# 100002                            0  Business Entity Type 3      0.083037
# 100003                            0                  School      0.311267
# 100004                            0              Government           NaN
# 100006                            0  Business Entity Type 3           NaN
# 100007                            1                Religion           NaN
# 100008                            0                   Other           NaN
# 100009                            0  Business Entity Type 3      0.774761
# 100010                            1                   Other           NaN
# 100011                            0                     XNA      0.587334
# 100012                            0             Electricity           NaN
#
#             EXT_SOURCE_2  EXT_SOURCE_3  APARTMENTS_AVG  BASEMENTAREA_AVG  \
# SK_ID_CURR
# 100002          0.262949      0.139376          0.0247            0.0369
# 100003          0.622246           NaN          0.0959            0.0529
# 100004          0.555912      0.729567             NaN               NaN
# 100006          0.650442           NaN             NaN               NaN
# 100007          0.322738           NaN             NaN               NaN
# 100008          0.354225      0.621226             NaN               NaN
# 100009          0.724000      0.492060             NaN               NaN
# 100010          0.714279      0.540654             NaN               NaN
# 100011          0.205747      0.751724             NaN               NaN
# 100012          0.746644           NaN             NaN               NaN
#
#             YEARS_BEGINEXPLUATATION_AVG  YEARS_BUILD_AVG  COMMONAREA_AVG  \
# SK_ID_CURR
# 100002                           0.9722           0.6192          0.0143
# 100003                           0.9851           0.7960          0.0605
# 100004                              NaN              NaN             NaN
# 100006                              NaN              NaN             NaN
# 100007                              NaN              NaN             NaN
# 100008                              NaN              NaN             NaN
# 100009                              NaN              NaN             NaN
# 100010                              NaN              NaN             NaN
# 100011                              NaN              NaN             NaN
# 100012                              NaN              NaN             NaN
#
#             ELEVATORS_AVG  ENTRANCES_AVG  FLOORSMAX_AVG  FLOORSMIN_AVG  \
# SK_ID_CURR
# 100002               0.00         0.0690         0.0833         0.1250
# 100003               0.08         0.0345         0.2917         0.3333
# 100004                NaN            NaN            NaN            NaN
# 100006                NaN            NaN            NaN            NaN
# 100007                NaN            NaN            NaN            NaN
# 100008                NaN            NaN            NaN            NaN
# 100009                NaN            NaN            NaN            NaN
# 100010                NaN            NaN            NaN            NaN
# 100011                NaN            NaN            NaN            NaN
# 100012                NaN            NaN            NaN            NaN
#
#             LANDAREA_AVG  LIVINGAPARTMENTS_AVG  LIVINGAREA_AVG  \
# SK_ID_CURR
# 100002            0.0369                0.0202          0.0190
# 100003            0.0130                0.0773          0.0549
# 100004               NaN                   NaN             NaN
# 100006               NaN                   NaN             NaN
# 100007               NaN                   NaN             NaN
# 100008               NaN                   NaN             NaN
# 100009               NaN                   NaN             NaN
# 100010               NaN                   NaN             NaN
# 100011               NaN                   NaN             NaN
# 100012               NaN                   NaN             NaN
#
#             NONLIVINGAPARTMENTS_AVG  NONLIVINGAREA_AVG  APARTMENTS_MODE  \
# SK_ID_CURR
# 100002                       0.0000             0.0000           0.0252
# 100003                       0.0039             0.0098           0.0924
# 100004                          NaN                NaN              NaN
# 100006                          NaN                NaN              NaN
# 100007                          NaN                NaN              NaN
# 100008                          NaN                NaN              NaN
# 100009                          NaN                NaN              NaN
# 100010                          NaN                NaN              NaN
# 100011                          NaN                NaN              NaN
# 100012                          NaN                NaN              NaN
#
#             BASEMENTAREA_MODE  YEARS_BEGINEXPLUATATION_MODE  YEARS_BUILD_MODE  \
# SK_ID_CURR
# 100002                 0.0383                        0.9722            0.6341
# 100003                 0.0538                        0.9851            0.8040
# 100004                    NaN                           NaN               NaN
# 100006                    NaN                           NaN               NaN
# 100007                    NaN                           NaN               NaN
# 100008                    NaN                           NaN               NaN
# 100009                    NaN                           NaN               NaN
# 100010                    NaN                           NaN               NaN
# 100011                    NaN                           NaN               NaN
# 100012                    NaN                           NaN               NaN
#
#             COMMONAREA_MODE  ELEVATORS_MODE  ENTRANCES_MODE  FLOORSMAX_MODE  \
# SK_ID_CURR
# 100002               0.0144          0.0000          0.0690          0.0833
# 100003               0.0497          0.0806          0.0345          0.2917
# 100004                  NaN             NaN             NaN             NaN
# 100006                  NaN             NaN             NaN             NaN
# 100007                  NaN             NaN             NaN             NaN
# 100008                  NaN             NaN             NaN             NaN
# 100009                  NaN             NaN             NaN             NaN
# 100010                  NaN             NaN             NaN             NaN
# 100011                  NaN             NaN             NaN             NaN
# 100012                  NaN             NaN             NaN             NaN
#
#             FLOORSMIN_MODE  LANDAREA_MODE  LIVINGAPARTMENTS_MODE  \
# SK_ID_CURR
# 100002              0.1250         0.0377                  0.022
# 100003              0.3333         0.0128                  0.079
# 100004                 NaN            NaN                    NaN
# 100006                 NaN            NaN                    NaN
# 100007                 NaN            NaN                    NaN
# 100008                 NaN            NaN                    NaN
# 100009                 NaN            NaN                    NaN
# 100010                 NaN            NaN                    NaN
# 100011                 NaN            NaN                    NaN
# 100012                 NaN            NaN                    NaN
#
#             LIVINGAREA_MODE  NONLIVINGAPARTMENTS_MODE  NONLIVINGAREA_MODE  \
# SK_ID_CURR
# 100002               0.0198                       0.0                 0.0
# 100003               0.0554                       0.0                 0.0
# 100004                  NaN                       NaN                 NaN
# 100006                  NaN                       NaN                 NaN
# 100007                  NaN                       NaN                 NaN
# 100008                  NaN                       NaN                 NaN
# 100009                  NaN                       NaN                 NaN
# 100010                  NaN                       NaN                 NaN
# 100011                  NaN                       NaN                 NaN
# 100012                  NaN                       NaN                 NaN
#
#             APARTMENTS_MEDI  BASEMENTAREA_MEDI  YEARS_BEGINEXPLUATATION_MEDI  \
# SK_ID_CURR
# 100002               0.0250             0.0369                        0.9722
# 100003               0.0968             0.0529                        0.9851
# 100004                  NaN                NaN                           NaN
# 100006                  NaN                NaN                           NaN
# 100007                  NaN                NaN                           NaN
# 100008                  NaN                NaN                           NaN
# 100009                  NaN                NaN                           NaN
# 100010                  NaN                NaN                           NaN
# 100011                  NaN                NaN                           NaN
# 100012                  NaN                NaN                           NaN
#
#             YEARS_BUILD_MEDI  COMMONAREA_MEDI  ELEVATORS_MEDI  ENTRANCES_MEDI  \
# SK_ID_CURR
# 100002                0.6243           0.0144            0.00          0.0690
# 100003                0.7987           0.0608            0.08          0.0345
# 100004                   NaN              NaN             NaN             NaN
# 100006                   NaN              NaN             NaN             NaN
# 100007                   NaN              NaN             NaN             NaN
# 100008                   NaN              NaN             NaN             NaN
# 100009                   NaN              NaN             NaN             NaN
# 100010                   NaN              NaN             NaN             NaN
# 100011                   NaN              NaN             NaN             NaN
# 100012                   NaN              NaN             NaN             NaN
#
#             FLOORSMAX_MEDI  FLOORSMIN_MEDI  LANDAREA_MEDI  \
# SK_ID_CURR
# 100002              0.0833          0.1250         0.0375
# 100003              0.2917          0.3333         0.0132
# 100004                 NaN             NaN            NaN
# 100006                 NaN             NaN            NaN
# 100007                 NaN             NaN            NaN
# 100008                 NaN             NaN            NaN
# 100009                 NaN             NaN            NaN
# 100010                 NaN             NaN            NaN
# 100011                 NaN             NaN            NaN
# 100012                 NaN             NaN            NaN
#
#             LIVINGAPARTMENTS_MEDI  LIVINGAREA_MEDI  NONLIVINGAPARTMENTS_MEDI  \
# SK_ID_CURR
# 100002                     0.0205           0.0193                    0.0000
# 100003                     0.0787           0.0558                    0.0039
# 100004                        NaN              NaN                       NaN
# 100006                        NaN              NaN                       NaN
# 100007                        NaN              NaN                       NaN
# 100008                        NaN              NaN                       NaN
# 100009                        NaN              NaN                       NaN
# 100010                        NaN              NaN                       NaN
# 100011                        NaN              NaN                       NaN
# 100012                        NaN              NaN                       NaN
#
#             NONLIVINGAREA_MEDI FONDKAPREMONT_MODE  HOUSETYPE_MODE  \
# SK_ID_CURR
# 100002                    0.00   reg oper account  block of flats
# 100003                    0.01   reg oper account  block of flats
# 100004                     NaN                NaN             NaN
# 100006                     NaN                NaN             NaN
# 100007                     NaN                NaN             NaN
# 100008                     NaN                NaN             NaN
# 100009                     NaN                NaN             NaN
# 100010                     NaN                NaN             NaN
# 100011                     NaN                NaN             NaN
# 100012                     NaN                NaN             NaN
#
#             TOTALAREA_MODE WALLSMATERIAL_MODE EMERGENCYSTATE_MODE  \
# SK_ID_CURR
# 100002              0.0149       Stone, brick                  No
# 100003              0.0714              Block                  No
# 100004                 NaN                NaN                 NaN
# 100006                 NaN                NaN                 NaN
# 100007                 NaN                NaN                 NaN
# 100008                 NaN                NaN                 NaN
# 100009                 NaN                NaN                 NaN
# 100010                 NaN                NaN                 NaN
# 100011                 NaN                NaN                 NaN
# 100012                 NaN                NaN                 NaN
#
#             OBS_30_CNT_SOCIAL_CIRCLE  DEF_30_CNT_SOCIAL_CIRCLE  \
# SK_ID_CURR
# 100002                           2.0                       2.0
# 100003                           1.0                       0.0
# 100004                           0.0                       0.0
# 100006                           2.0                       0.0
# 100007                           0.0                       0.0
# 100008                           0.0                       0.0
# 100009                           1.0                       0.0
# 100010                           2.0                       0.0
# 100011                           1.0                       0.0
# 100012                           2.0                       0.0
#
#             OBS_60_CNT_SOCIAL_CIRCLE  DEF_60_CNT_SOCIAL_CIRCLE  \
# SK_ID_CURR
# 100002                           2.0                       2.0
# 100003                           1.0                       0.0
# 100004                           0.0                       0.0
# 100006                           2.0                       0.0
# 100007                           0.0                       0.0
# 100008                           0.0                       0.0
# 100009                           1.0                       0.0
# 100010                           2.0                       0.0
# 100011                           1.0                       0.0
# 100012                           2.0                       0.0
#
#             DAYS_LAST_PHONE_CHANGE  FLAG_DOCUMENT_2  FLAG_DOCUMENT_3  \
# SK_ID_CURR
# 100002                     -1134.0                0                1
# 100003                      -828.0                0                1
# 100004                      -815.0                0                0
# 100006                      -617.0                0                1
# 100007                     -1106.0                0                0
# 100008                     -2536.0                0                1
# 100009                     -1562.0                0                0
# 100010                     -1070.0                0                1
# 100011                         0.0                0                1
# 100012                     -1673.0                0                0
#
#             FLAG_DOCUMENT_4  FLAG_DOCUMENT_5  FLAG_DOCUMENT_6  \
# SK_ID_CURR
# 100002                    0                0                0
# 100003                    0                0                0
# 100004                    0                0                0
# 100006                    0                0                0
# 100007                    0                0                0
# 100008                    0                0                0
# 100009                    0                0                0
# 100010                    0                0                0
# 100011                    0                0                0
# 100012                    0                0                0
#
#             FLAG_DOCUMENT_7  FLAG_DOCUMENT_8  FLAG_DOCUMENT_9  \
# SK_ID_CURR
# 100002                    0                0                0
# 100003                    0                0                0
# 100004                    0                0                0
# 100006                    0                0                0
# 100007                    0                1                0
# 100008                    0                0                0
# 100009                    0                1                0
# 100010                    0                0                0
# 100011                    0                0                0
# 100012                    0                0                0
#
#             FLAG_DOCUMENT_10  FLAG_DOCUMENT_11  FLAG_DOCUMENT_12  \
# SK_ID_CURR
# 100002                     0                 0                 0
# 100003                     0                 0                 0
# 100004                     0                 0                 0
# 100006                     0                 0                 0
# 100007                     0                 0                 0
# 100008                     0                 0                 0
# 100009                     0                 0                 0
# 100010                     0                 0                 0
# 100011                     0                 0                 0
# 100012                     0                 0                 0
#
#             FLAG_DOCUMENT_13  FLAG_DOCUMENT_14  FLAG_DOCUMENT_15  \
# SK_ID_CURR
# 100002                     0                 0                 0
# 100003                     0                 0                 0
# 100004                     0                 0                 0
# 100006                     0                 0                 0
# 100007                     0                 0                 0
# 100008                     0                 0                 0
# 100009                     0                 1                 0
# 100010                     0                 0                 0
# 100011                     0                 0                 0
# 100012                     0                 0                 0
#
#             FLAG_DOCUMENT_16  FLAG_DOCUMENT_17  FLAG_DOCUMENT_18  \
# SK_ID_CURR
# 100002                     0                 0                 0
# 100003                     0                 0                 0
# 100004                     0                 0                 0
# 100006                     0                 0                 0
# 100007                     0                 0                 0
# 100008                     0                 0                 0
# 100009                     0                 0                 0
# 100010                     0                 0                 0
# 100011                     0                 0                 0
# 100012                     0                 0                 0
#
#             FLAG_DOCUMENT_19  FLAG_DOCUMENT_20  FLAG_DOCUMENT_21  \
# SK_ID_CURR
# 100002                     0                 0                 0
# 100003                     0                 0                 0
# 100004                     0                 0                 0
# 100006                     0                 0                 0
# 100007                     0                 0                 0
# 100008                     0                 0                 0
# 100009                     0                 0                 0
# 100010                     0                 0                 0
# 100011                     0                 0                 0
# 100012                     0                 0                 0
#
#             AMT_REQ_CREDIT_BUREAU_HOUR  AMT_REQ_CREDIT_BUREAU_DAY  \
# SK_ID_CURR
# 100002                             0.0                        0.0
# 100003                             0.0                        0.0
# 100004                             0.0                        0.0
# 100006                             NaN                        NaN
# 100007                             0.0                        0.0
# 100008                             0.0                        0.0
# 100009                             0.0                        0.0
# 100010                             0.0                        0.0
# 100011                             0.0                        0.0
# 100012                             NaN                        NaN
#
#             AMT_REQ_CREDIT_BUREAU_WEEK  AMT_REQ_CREDIT_BUREAU_MON  \
# SK_ID_CURR
# 100002                             0.0                        0.0
# 100003                             0.0                        0.0
# 100004                             0.0                        0.0
# 100006                             NaN                        NaN
# 100007                             0.0                        0.0
# 100008                             0.0                        0.0
# 100009                             0.0                        1.0
# 100010                             0.0                        0.0
# 100011                             0.0                        0.0
# 100012                             NaN                        NaN
#
#             AMT_REQ_CREDIT_BUREAU_QRT  AMT_REQ_CREDIT_BUREAU_YEAR    set  \
# SK_ID_CURR
# 100002                            0.0                         1.0  train
# 100003                            0.0                         0.0  train
# 100004                            0.0                         0.0  train
# 100006                            NaN                         NaN  train
# 100007                            0.0                         0.0  train
# 100008                            1.0                         1.0  train
# 100009                            1.0                         2.0  train
# 100010                            0.0                         0.0  train
# 100011                            0.0                         1.0  train
# 100012                            NaN                         NaN  train
#
#             COUNT(bureau)  MAX(bureau.AMT_ANNUITY)  \
# SK_ID_CURR
# 100002                  8                      0.0
# 100003                  4                      NaN
# 100004                  2                      NaN
# 100006                  0                      NaN
# 100007                  1                      NaN
# 100008                  3                      NaN
# 100009                 18                      NaN
# 100010                  2                      NaN
# 100011                  4                      NaN
# 100012                  0                      NaN
#
#             MAX(bureau.AMT_CREDIT_MAX_OVERDUE)  MAX(bureau.AMT_CREDIT_SUM)  \
# SK_ID_CURR
# 100002                                5043.645                    450000.0
# 100003                                   0.000                    810000.0
# 100004                                   0.000                     94537.8
# 100006                                     NaN                         NaN
# 100007                                   0.000                    146250.0
# 100008                                   0.000                    267606.0
# 100009                                   0.000                   1777500.0
# 100010                                     NaN                    675000.0
# 100011                               10147.230                    145242.0
# 100012                                     NaN                         NaN
#
#             MAX(bureau.AMT_CREDIT_SUM_DEBT)  MAX(bureau.AMT_CREDIT_SUM_LIMIT)  \
# SK_ID_CURR
# 100002                             245781.0                         31988.565
# 100003                                  0.0                        810000.000
# 100004                                  0.0                             0.000
# 100006                                  NaN                               NaN
# 100007                                  0.0                             0.000
# 100008                             240057.0                             0.000
# 100009                             557959.5                             0.000
# 100010                             348007.5                             0.000
# 100011                                  0.0                             0.000
# 100012                                  NaN                               NaN
#
#             MAX(bureau.AMT_CREDIT_SUM_OVERDUE)  \
# SK_ID_CURR
# 100002                                     0.0
# 100003                                     0.0
# 100004                                     0.0
# 100006                                     NaN
# 100007                                     0.0
# 100008                                     0.0
# 100009                                     0.0
# 100010                                     0.0
# 100011                                     0.0
# 100012                                     NaN
#
#             MAX(bureau.CNT_CREDIT_PROLONG)  MAX(bureau.CREDIT_DAY_OVERDUE)  \
# SK_ID_CURR
# 100002                                 0.0                             0.0
# 100003                                 0.0                             0.0
# 100004                                 0.0                             0.0
# 100006                                 NaN                             NaN
# 100007                                 0.0                             0.0
# 100008                                 0.0                             0.0
# 100009                                 0.0                             0.0
# 100010                                 0.0                             0.0
# 100011                                 0.0                             0.0
# 100012                                 NaN                             NaN
#
#             MAX(bureau.DAYS_CREDIT)  MAX(bureau.DAYS_CREDIT_ENDDATE)  \
# SK_ID_CURR
# 100002                       -103.0                            780.0
# 100003                       -606.0                           1216.0
# 100004                       -408.0                           -382.0
# 100006                          NaN                              NaN
# 100007                      -1149.0                           -783.0
# 100008                        -78.0                            471.0
# 100009                       -239.0                           1402.0
# 100010                      -1138.0                            689.0
# 100011                      -1309.0                           -860.0
# 100012                          NaN                              NaN
#
#             MAX(bureau.DAYS_CREDIT_UPDATE)  MAX(bureau.DAYS_ENDDATE_FACT)  \
# SK_ID_CURR
# 100002                                -7.0                          -36.0
# 100003                               -43.0                         -540.0
# 100004                              -382.0                         -382.0
# 100006                                 NaN                            NaN
# 100007                              -783.0                         -783.0
# 100008                               -16.0                         -790.0
# 100009                               -23.0                         -313.0
# 100010                               -18.0                        -1138.0
# 100011                              -965.0                         -968.0
# 100012                                 NaN                            NaN
#
#             MEAN(bureau.AMT_ANNUITY)  MEAN(bureau.AMT_CREDIT_MAX_OVERDUE)  \
# SK_ID_CURR
# 100002                           0.0                             1681.029
# 100003                           NaN                                0.000
# 100004                           NaN                                0.000
# 100006                           NaN                                  NaN
# 100007                           NaN                                0.000
# 100008                           NaN                                0.000
# 100009                           NaN                                0.000
# 100010                           NaN                                  NaN
# 100011                           NaN                             5073.615
# 100012                           NaN                                  NaN
#
#             MEAN(bureau.AMT_CREDIT_SUM)  MEAN(bureau.AMT_CREDIT_SUM_DEBT)  \
# SK_ID_CURR
# 100002                    108131.945625                      49156.200000
# 100003                    254350.125000                          0.000000
# 100004                     94518.900000                          0.000000
# 100006                              NaN                               NaN
# 100007                    146250.000000                          0.000000
# 100008                    156148.500000                      80019.000000
# 100009                    266711.750000                      76953.535714
# 100010                    495000.000000                     174003.750000
# 100011                    108807.075000                          0.000000
# 100012                              NaN                               NaN
#
#             MEAN(bureau.AMT_CREDIT_SUM_LIMIT)  \
# SK_ID_CURR
# 100002                             7997.14125
# 100003                           202500.00000
# 100004                                0.00000
# 100006                                    NaN
# 100007                                0.00000
# 100008                                0.00000
# 100009                                0.00000
# 100010                                0.00000
# 100011                                0.00000
# 100012                                    NaN
#
#             MEAN(bureau.AMT_CREDIT_SUM_OVERDUE)  \
# SK_ID_CURR
# 100002                                      0.0
# 100003                                      0.0
# 100004                                      0.0
# 100006                                      NaN
# 100007                                      0.0
# 100008                                      0.0
# 100009                                      0.0
# 100010                                      0.0
# 100011                                      0.0
# 100012                                      NaN
#
#             MEAN(bureau.CNT_CREDIT_PROLONG)  MEAN(bureau.CREDIT_DAY_OVERDUE)  \
# SK_ID_CURR
# 100002                                  0.0                              0.0
# 100003                                  0.0                              0.0
# 100004                                  0.0                              0.0
# 100006                                  NaN                              NaN
# 100007                                  0.0                              0.0
# 100008                                  0.0                              0.0
# 100009                                  0.0                              0.0
# 100010                                  0.0                              0.0
# 100011                                  0.0                              0.0
# 100012                                  NaN                              NaN
#
#             MEAN(bureau.DAYS_CREDIT)  MEAN(bureau.DAYS_CREDIT_ENDDATE)  \
# SK_ID_CURR
# 100002                   -874.000000                       -349.000000
# 100003                  -1400.750000                       -544.500000
# 100004                   -867.000000                       -488.500000
# 100006                           NaN                               NaN
# 100007                  -1149.000000                       -783.000000
# 100008                   -757.333333                       -391.333333
# 100009                  -1271.500000                       -794.937500
# 100010                  -1939.500000                       -119.500000
# 100011                  -1773.000000                      -1293.250000
# 100012                           NaN                               NaN
#
#             MEAN(bureau.DAYS_CREDIT_UPDATE)  MEAN(bureau.DAYS_ENDDATE_FACT)  \
# SK_ID_CURR
# 100002                          -499.875000                     -697.500000
# 100003                          -816.000000                    -1097.333333
# 100004                          -532.000000                     -532.500000
# 100006                                  NaN                             NaN
# 100007                          -783.000000                     -783.000000
# 100008                          -611.000000                     -909.000000
# 100009                          -851.611111                    -1108.500000
# 100010                          -578.000000                    -1138.000000
# 100011                         -1454.750000                    -1463.250000
# 100012                                  NaN                             NaN
#
#             MIN(bureau.AMT_ANNUITY)  MIN(bureau.AMT_CREDIT_MAX_OVERDUE)  \
# SK_ID_CURR
# 100002                          0.0                                 0.0
# 100003                          NaN                                 0.0
# 100004                          NaN                                 0.0
# 100006                          NaN                                 NaN
# 100007                          NaN                                 0.0
# 100008                          NaN                                 0.0
# 100009                          NaN                                 0.0
# 100010                          NaN                                 NaN
# 100011                          NaN                                 0.0
# 100012                          NaN                                 NaN
#
#             MIN(bureau.AMT_CREDIT_SUM)  MIN(bureau.AMT_CREDIT_SUM_DEBT)  \
# SK_ID_CURR
# 100002                             0.0                              0.0
# 100003                         22248.0                              0.0
# 100004                         94500.0                              0.0
# ...
# 100010                                                 NaN
# 100011                                                 0.0
# 100012                                                 NaN
#
#             STD(credit.previous.NFLAG_LAST_APPL_IN_DAY)  \
# SK_ID_CURR
# 100002                                              NaN
# 100003                                              NaN
# 100004                                              NaN
# 100006                                              0.0
# 100007                                              NaN
# 100008                                              NaN
# 100009                                              NaN
# 100010                                              NaN
# 100011                                              0.0
# 100012                                              NaN
#
#             STD(credit.previous.RATE_DOWN_PAYMENT)  \
# SK_ID_CURR
# 100002                                         NaN
# 100003                                         NaN
# 100004                                         NaN
# 100006                                         NaN
# 100007                                         NaN
# 100008                                         NaN
# 100009                                         NaN
# 100010                                         NaN
# 100011                                         NaN
# 100012                                         NaN
#
#             STD(credit.previous.RATE_INTEREST_PRIMARY)  \
# SK_ID_CURR
# 100002                                             NaN
# 100003                                             NaN
# 100004                                             NaN
# 100006                                             NaN
# 100007                                             NaN
# 100008                                             NaN
# 100009                                             NaN
# 100010                                             NaN
# 100011                                             NaN
# 100012                                             NaN
#
#             STD(credit.previous.RATE_INTEREST_PRIVILEGED)  \
# SK_ID_CURR
# 100002                                                NaN
# 100003                                                NaN
# 100004                                                NaN
# 100006                                                NaN
# 100007                                                NaN
# 100008                                                NaN
# 100009                                                NaN
# 100010                                                NaN
# 100011                                                NaN
# 100012                                                NaN
#
#             STD(credit.previous.SELLERPLACE_AREA)  \
# SK_ID_CURR
# 100002                                        NaN
# 100003                                        NaN
# 100004                                        NaN
# 100006                                        0.0
# 100007                                        NaN
# 100008                                        NaN
# 100009                                        NaN
# 100010                                        NaN
# 100011                                        0.0
# 100012                                        NaN
#
#             SUM(credit.previous.AMT_ANNUITY)  \
# SK_ID_CURR
# 100002                                   0.0
# 100003                                   0.0
# 100004                                   0.0
# 100006                               81000.0
# 100007                                   0.0
# 100008                                   0.0
# 100009                                   0.0
# 100010                                   0.0
# 100011                              666000.0
# 100012                                   0.0
#
#             SUM(credit.previous.AMT_APPLICATION)  \
# SK_ID_CURR
# 100002                                       0.0
# 100003                                       0.0
# 100004                                       0.0
# 100006                                 1620000.0
# 100007                                       0.0
# 100008                                       0.0
# 100009                                       0.0
# 100010                                       0.0
# 100011                                       0.0
# 100012                                       0.0
#
#             SUM(credit.previous.AMT_CREDIT)  \
# SK_ID_CURR
# 100002                                  0.0
# 100003                                  0.0
# 100004                                  0.0
# 100006                            1620000.0
# 100007                                  0.0
# 100008                                  0.0
# 100009                                  0.0
# 100010                                  0.0
# 100011                           13320000.0
# 100012                                  0.0
#
#             SUM(credit.previous.AMT_DOWN_PAYMENT)  \
# SK_ID_CURR
# 100002                                        0.0
# 100003                                        0.0
# 100004                                        0.0
# 100006                                        0.0
# 100007                                        0.0
# 100008                                        0.0
# 100009                                        0.0
# 100010                                        0.0
# 100011                                        0.0
# 100012                                        0.0
#
#             SUM(credit.previous.AMT_GOODS_PRICE)  \
# SK_ID_CURR
# 100002                                       0.0
# 100003                                       0.0
# 100004                                       0.0
# 100006                                 1620000.0
# 100007                                       0.0
# 100008                                       0.0
# 100009                                       0.0
# 100010                                       0.0
# 100011                                       0.0
# 100012                                       0.0
#
#             SUM(credit.previous.CNT_PAYMENT)  \
# SK_ID_CURR
# 100002                                   0.0
# 100003                                   0.0
# 100004                                   0.0
# 100006                                   0.0
# 100007                                   0.0
# 100008                                   0.0
# 100009                                   0.0
# 100010                                   0.0
# 100011                                   0.0
# 100012                                   0.0
#
#             SUM(credit.previous.DAYS_DECISION)  \
# SK_ID_CURR
# 100002                                     0.0
# 100003                                     0.0
# 100004                                     0.0
# 100006                                 -1086.0
# 100007                                     0.0
# 100008                                     0.0
# 100009                                     0.0
# 100010                                     0.0
# 100011                               -168646.0
# 100012                                     0.0
#
#             SUM(credit.previous.DAYS_FIRST_DRAWING)  \
# SK_ID_CURR
# 100002                                          0.0
# 100003                                          0.0
# 100004                                          0.0
# 100006                                    2191458.0
# 100007                                          0.0
# 100008                                          0.0
# 100009                                          0.0
# 100010                                          0.0
# 100011                                    -168498.0
# 100012                                          0.0
#
#             SUM(credit.previous.DAYS_FIRST_DUE)  \
# SK_ID_CURR
# 100002                                      0.0
# 100003                                      0.0
# 100004                                      0.0
# 100006                                2191458.0
# 100007                                      0.0
# 100008                                      0.0
# 100009                                      0.0
# 100010                                      0.0
# 100011                                -164946.0
# 100012                                      0.0
#
#             SUM(credit.previous.DAYS_LAST_DUE)  \
# SK_ID_CURR
# 100002                                     0.0
# 100003                                     0.0
# 100004                                     0.0
# 100006                               2191458.0
# 100007                                     0.0
# 100008                                     0.0
# 100009                                     0.0
# 100010                                     0.0
# 100011                                -93018.0
# 100012                                     0.0
#
#             SUM(credit.previous.DAYS_LAST_DUE_1ST_VERSION)  \
# SK_ID_CURR
# 100002                                                 0.0
# 100003                                                 0.0
# 100004                                                 0.0
# 100006                                           2191458.0
# 100007                                                 0.0
# 100008                                                 0.0
# 100009                                                 0.0
# 100010                                                 0.0
# 100011                                          27027982.0
# 100012                                                 0.0
#
#             SUM(credit.previous.DAYS_TERMINATION)  \
# SK_ID_CURR
# 100002                                        0.0
# 100003                                        0.0
# 100004                                        0.0
# 100006                                  2191458.0
# 100007                                        0.0
# 100008                                        0.0
# 100009                                        0.0
# 100010                                        0.0
# 100011                                 27027982.0
# 100012                                        0.0
#
#             SUM(credit.previous.HOUR_APPR_PROCESS_START)  \
# SK_ID_CURR
# 100002                                               0.0
# 100003                                               0.0
# 100004                                               0.0
# 100006                                              90.0
# 100007                                               0.0
# 100008                                               0.0
# 100009                                               0.0
# 100010                                               0.0
# 100011                                             740.0
# 100012                                               0.0
#
#             SUM(credit.previous.NFLAG_INSURED_ON_APPROVAL)  \
# SK_ID_CURR
# 100002                                                 0.0
# 100003                                                 0.0
# 100004                                                 0.0
# 100006                                                 0.0
# 100007                                                 0.0
# 100008                                                 0.0
# 100009                                                 0.0
# 100010                                                 0.0
# 100011                                                 0.0
# 100012                                                 0.0
#
#             SUM(credit.previous.NFLAG_LAST_APPL_IN_DAY)  \
# SK_ID_CURR
# 100002                                              0.0
# 100003                                              0.0
# 100004                                              0.0
# 100006                                              6.0
# 100007                                              0.0
# 100008                                              0.0
# 100009                                              0.0
# 100010                                              0.0
# 100011                                             74.0
# 100012                                              0.0
#
#             SUM(credit.previous.RATE_DOWN_PAYMENT)  \
# SK_ID_CURR
# 100002                                         0.0
# 100003                                         0.0
# 100004                                         0.0
# 100006                                         0.0
# 100007                                         0.0
# 100008                                         0.0
# 100009                                         0.0
# 100010                                         0.0
# 100011                                         0.0
# 100012                                         0.0
#
#             SUM(credit.previous.RATE_INTEREST_PRIMARY)  \
# SK_ID_CURR
# 100002                                             0.0
# 100003                                             0.0
# 100004                                             0.0
# 100006                                             0.0
# 100007                                             0.0
# 100008                                             0.0
# 100009                                             0.0
# 100010                                             0.0
# 100011                                             0.0
# 100012                                             0.0
#
#             SUM(credit.previous.RATE_INTEREST_PRIVILEGED)  \
# SK_ID_CURR
# 100002                                                0.0
# 100003                                                0.0
# 100004                                                0.0
# 100006                                                0.0
# 100007                                                0.0
# 100008                                                0.0
# 100009                                                0.0
# 100010                                                0.0
# 100011                                                0.0
# 100012                                                0.0
#
#             SUM(credit.previous.SELLERPLACE_AREA)
# SK_ID_CURR
# 100002                                        0.0
# 100003                                        0.0
# 100004                                        0.0
# 100006                                       -6.0
# 100007                                        0.0
# 100008                                        0.0
# 100009                                        0.0
# 100010                                        0.0
# 100011                                        0.0
# 100012                                        0.0
#
# [10 rows x 2213 columns]

# %%
feature_names[-20:]
# Out:
# [<Feature: STD(credit.previous.SELLERPLACE_AREA)>,
#  <Feature: SUM(credit.previous.AMT_ANNUITY)>,
#  <Feature: SUM(credit.previous.AMT_APPLICATION)>,
#  <Feature: SUM(credit.previous.AMT_CREDIT)>,
#  <Feature: SUM(credit.previous.AMT_DOWN_PAYMENT)>,
#  <Feature: SUM(credit.previous.AMT_GOODS_PRICE)>,
#  <Feature: SUM(credit.previous.CNT_PAYMENT)>,
#  <Feature: SUM(credit.previous.DAYS_DECISION)>,
#  <Feature: SUM(credit.previous.DAYS_FIRST_DRAWING)>,
#  <Feature: SUM(credit.previous.DAYS_FIRST_DUE)>,
#  <Feature: SUM(credit.previous.DAYS_LAST_DUE)>,
#  <Feature: SUM(credit.previous.DAYS_LAST_DUE_1ST_VERSION)>,
#  <Feature: SUM(credit.previous.DAYS_TERMINATION)>,
#  <Feature: SUM(credit.previous.HOUR_APPR_PROCESS_START)>,
#  <Feature: SUM(credit.previous.NFLAG_INSURED_ON_APPROVAL)>,
#  <Feature: SUM(credit.previous.NFLAG_LAST_APPL_IN_DAY)>,
#  <Feature: SUM(credit.previous.RATE_DOWN_PAYMENT)>,
#  <Feature: SUM(credit.previous.RATE_INTEREST_PRIMARY)>,
#  <Feature: SUM(credit.previous.RATE_INTEREST_PRIVILEGED)>,
#  <Feature: SUM(credit.previous.SELLERPLACE_AREA)>]

# %%
#Specifiy the aggregation primitives
feature_matrix_spec, feature_names_spec = ft.dfs(entityset = es, target_dataframe_name = 'app',  
                                                 agg_primitives = ['sum', 'count', 'min', 'max', 'mean', 'mode'], 
                                                 max_depth = 2, features_only = False, verbose = True)
# Out:
# Built 1211 features
# Elapsed: 00:05 | Progress: 100%|██████████

# %%
pd.options.display.max_columns = 1000
feature_matrix_spec.head(10)
# Out:
#             TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# SK_ID_CURR
# 100002         1.0         Cash loans           M            N
# 100003         0.0         Cash loans           F            N
# 100004         0.0    Revolving loans           M            Y
# 100006         0.0         Cash loans           F            N
# 100007         0.0         Cash loans           M            N
# 100008         0.0         Cash loans           M            N
# 100009         0.0         Cash loans           F            Y
# 100010         0.0         Cash loans           M            Y
# 100011         0.0         Cash loans           F            N
# 100012         0.0    Revolving loans           M            N
#
#            FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  \
# SK_ID_CURR
# 100002                   Y             0          202500.0    406597.5
# 100003                   N             0          270000.0   1293502.5
# 100004                   Y             0           67500.0    135000.0
# 100006                   Y             0          135000.0    312682.5
# 100007                   Y             0          121500.0    513000.0
# 100008                   Y             0           99000.0    490495.5
# 100009                   Y             1          171000.0   1560726.0
# 100010                   Y             0          360000.0   1530000.0
# 100011                   Y             0          112500.0   1019610.0
# 100012                   Y             0          135000.0    405000.0
#
#             AMT_ANNUITY  AMT_GOODS_PRICE  NAME_TYPE_SUITE  \
# SK_ID_CURR
# 100002          24700.5         351000.0    Unaccompanied
# 100003          35698.5        1129500.0           Family
# 100004           6750.0         135000.0    Unaccompanied
# 100006          29686.5         297000.0    Unaccompanied
# 100007          21865.5         513000.0    Unaccompanied
# 100008          27517.5         454500.0  Spouse, partner
# 100009          41301.0        1395000.0    Unaccompanied
# 100010          42075.0        1530000.0    Unaccompanied
# 100011          33826.5         913500.0         Children
# 100012          20250.0         405000.0    Unaccompanied
#
#                 NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# SK_ID_CURR
# 100002                   Working  Secondary / secondary special
# 100003             State servant               Higher education
# 100004                   Working  Secondary / secondary special
# 100006                   Working  Secondary / secondary special
# 100007                   Working  Secondary / secondary special
# 100008             State servant  Secondary / secondary special
# 100009      Commercial associate               Higher education
# 100010             State servant               Higher education
# 100011                 Pensioner  Secondary / secondary special
# 100012                   Working  Secondary / secondary special
#
#               NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  \
# SK_ID_CURR
# 100002      Single / not married  House / apartment
# 100003                   Married  House / apartment
# 100004      Single / not married  House / apartment
# 100006            Civil marriage  House / apartment
# 100007      Single / not married  House / apartment
# 100008                   Married  House / apartment
# 100009                   Married  House / apartment
# 100010                   Married  House / apartment
# 100011                   Married  House / apartment
# 100012      Single / not married  House / apartment
#
#             REGION_POPULATION_RELATIVE  DAYS_BIRTH  DAYS_EMPLOYED  \
# SK_ID_CURR
# 100002                        0.018801       -9461           -637
# 100003                        0.003541      -16765          -1188
# 100004                        0.010032      -19046           -225
# 100006                        0.008019      -19005          -3039
# 100007                        0.028663      -19932          -3038
# 100008                        0.035792      -16941          -1588
# 100009                        0.035792      -13778          -3130
# 100010                        0.003122      -18850           -449
# 100011                        0.018634      -20099         365243
# 100012                        0.019689      -14469          -2019
#
#             DAYS_REGISTRATION  DAYS_ID_PUBLISH  OWN_CAR_AGE  FLAG_MOBIL  \
# SK_ID_CURR
# 100002                -3648.0            -2120          NaN           1
# 100003                -1186.0             -291          NaN           1
# 100004                -4260.0            -2531         26.0           1
# 100006                -9833.0            -2437          NaN           1
# 100007                -4311.0            -3458          NaN           1
# 100008                -4970.0             -477          NaN           1
# 100009                -1213.0             -619         17.0           1
# 100010                -4597.0            -2379          8.0           1
# 100011                -7427.0            -3514          NaN           1
# 100012               -14437.0            -3992          NaN           1
#
#             FLAG_EMP_PHONE  FLAG_WORK_PHONE  FLAG_CONT_MOBILE  FLAG_PHONE  \
# SK_ID_CURR
# 100002                   1                0                 1           1
# 100003                   1                0                 1           1
# 100004                   1                1                 1           1
# 100006                   1                0                 1           0
# 100007                   1                0                 1           0
# 100008                   1                1                 1           1
# 100009                   1                0                 1           1
# 100010                   1                1                 1           0
# 100011                   0                0                 1           0
# 100012                   1                0                 1           0
#
#             FLAG_EMAIL OCCUPATION_TYPE  CNT_FAM_MEMBERS  REGION_RATING_CLIENT  \
# SK_ID_CURR
# 100002               0        Laborers              1.0                     2
# 100003               0      Core staff              2.0                     1
# 100004               0        Laborers              1.0                     2
# 100006               0        Laborers              2.0                     2
# 100007               0      Core staff              1.0                     2
# 100008               0        Laborers              2.0                     2
# 100009               0     Accountants              3.0                     2
# 100010               0        Managers              2.0                     3
# 100011               0             NaN              2.0                     2
# 100012               0        Laborers              1.0                     2
#
#             REGION_RATING_CLIENT_W_CITY WEEKDAY_APPR_PROCESS_START  \
# SK_ID_CURR
# 100002                                2                  WEDNESDAY
# 100003                                1                     MONDAY
# 100004                                2                     MONDAY
# 100006                                2                  WEDNESDAY
# 100007                                2                   THURSDAY
# 100008                                2                  WEDNESDAY
# 100009                                2                     SUNDAY
# 100010                                3                     MONDAY
# 100011                                2                  WEDNESDAY
# 100012                                2                   THURSDAY
#
#             HOUR_APPR_PROCESS_START  REG_REGION_NOT_LIVE_REGION  \
# SK_ID_CURR
# 100002                           10                           0
# 100003                           11                           0
# 100004                            9                           0
# 100006                           17                           0
# 100007                           11                           0
# 100008                           16                           0
# 100009                           16                           0
# 100010                           16                           0
# 100011                           14                           0
# 100012                            8                           0
#
#             REG_REGION_NOT_WORK_REGION  LIVE_REGION_NOT_WORK_REGION  \
# SK_ID_CURR
# 100002                               0                            0
# 100003                               0                            0
# 100004                               0                            0
# 100006                               0                            0
# 100007                               0                            0
# 100008                               0                            0
# 100009                               0                            0
# 100010                               0                            0
# 100011                               0                            0
# 100012                               0                            0
#
#             REG_CITY_NOT_LIVE_CITY  REG_CITY_NOT_WORK_CITY  \
# SK_ID_CURR
# 100002                           0                       0
# 100003                           0                       0
# 100004                           0                       0
# 100006                           0                       0
# 100007                           0                       1
# 100008                           0                       0
# 100009                           0                       0
# 100010                           0                       1
# 100011                           0                       0
# 100012                           0                       0
#
#             LIVE_CITY_NOT_WORK_CITY       ORGANIZATION_TYPE  EXT_SOURCE_1  \
# SK_ID_CURR
# 100002                            0  Business Entity Type 3      0.083037
# 100003                            0                  School      0.311267
# 100004                            0              Government           NaN
# 100006                            0  Business Entity Type 3           NaN
# 100007                            1                Religion           NaN
# 100008                            0                   Other           NaN
# 100009                            0  Business Entity Type 3      0.774761
# 100010                            1                   Other           NaN
# 100011                            0                     XNA      0.587334
# 100012                            0             Electricity           NaN
#
#             EXT_SOURCE_2  EXT_SOURCE_3  APARTMENTS_AVG  BASEMENTAREA_AVG  \
# SK_ID_CURR
# 100002          0.262949      0.139376          0.0247            0.0369
# 100003          0.622246           NaN          0.0959            0.0529
# 100004          0.555912      0.729567             NaN               NaN
# 100006          0.650442           NaN             NaN               NaN
# 100007          0.322738           NaN             NaN               NaN
# 100008          0.354225      0.621226             NaN               NaN
# 100009          0.724000      0.492060             NaN               NaN
# 100010          0.714279      0.540654             NaN               NaN
# 100011          0.205747      0.751724             NaN               NaN
# 100012          0.746644           NaN             NaN               NaN
#
#             YEARS_BEGINEXPLUATATION_AVG  YEARS_BUILD_AVG  COMMONAREA_AVG  \
# SK_ID_CURR
# 100002                           0.9722           0.6192          0.0143
# 100003                           0.9851           0.7960          0.0605
# 100004                              NaN              NaN             NaN
# 100006                              NaN              NaN             NaN
# 100007                              NaN              NaN             NaN
# 100008                              NaN              NaN             NaN
# 100009                              NaN              NaN             NaN
# 100010                              NaN              NaN             NaN
# 100011                              NaN              NaN             NaN
# 100012                              NaN              NaN             NaN
#
#             ELEVATORS_AVG  ENTRANCES_AVG  FLOORSMAX_AVG  FLOORSMIN_AVG  \
# SK_ID_CURR
# 100002               0.00         0.0690         0.0833         0.1250
# 100003               0.08         0.0345         0.2917         0.3333
# 100004                NaN            NaN            NaN            NaN
# 100006                NaN            NaN            NaN            NaN
# 100007                NaN            NaN            NaN            NaN
# 100008                NaN            NaN            NaN            NaN
# 100009                NaN            NaN            NaN            NaN
# 100010                NaN            NaN            NaN            NaN
# 100011                NaN            NaN            NaN            NaN
# 100012                NaN            NaN            NaN            NaN
#
#             LANDAREA_AVG  LIVINGAPARTMENTS_AVG  LIVINGAREA_AVG  \
# SK_ID_CURR
# 100002            0.0369                0.0202          0.0190
# 100003            0.0130                0.0773          0.0549
# 100004               NaN                   NaN             NaN
# 100006               NaN                   NaN             NaN
# 100007               NaN                   NaN             NaN
# 100008               NaN                   NaN             NaN
# 100009               NaN                   NaN             NaN
# 100010               NaN                   NaN             NaN
# 100011               NaN                   NaN             NaN
# 100012               NaN                   NaN             NaN
#
#             NONLIVINGAPARTMENTS_AVG  NONLIVINGAREA_AVG  APARTMENTS_MODE  \
# SK_ID_CURR
# 100002                       0.0000             0.0000           0.0252
# 100003                       0.0039             0.0098           0.0924
# 100004                          NaN                NaN              NaN
# 100006                          NaN                NaN              NaN
# 100007                          NaN                NaN              NaN
# 100008                          NaN                NaN              NaN
# 100009                          NaN                NaN              NaN
# 100010                          NaN                NaN              NaN
# 100011                          NaN                NaN              NaN
# 100012                          NaN                NaN              NaN
#
#             BASEMENTAREA_MODE  YEARS_BEGINEXPLUATATION_MODE  YEARS_BUILD_MODE  \
# SK_ID_CURR
# 100002                 0.0383                        0.9722            0.6341
# 100003                 0.0538                        0.9851            0.8040
# 100004                    NaN                           NaN               NaN
# 100006                    NaN                           NaN               NaN
# 100007                    NaN                           NaN               NaN
# 100008                    NaN                           NaN               NaN
# 100009                    NaN                           NaN               NaN
# 100010                    NaN                           NaN               NaN
# 100011                    NaN                           NaN               NaN
# 100012                    NaN                           NaN               NaN
#
#             COMMONAREA_MODE  ELEVATORS_MODE  ENTRANCES_MODE  FLOORSMAX_MODE  \
# SK_ID_CURR
# 100002               0.0144          0.0000          0.0690          0.0833
# 100003               0.0497          0.0806          0.0345          0.2917
# 100004                  NaN             NaN             NaN             NaN
# 100006                  NaN             NaN             NaN             NaN
# 100007                  NaN             NaN             NaN             NaN
# 100008                  NaN             NaN             NaN             NaN
# 100009                  NaN             NaN             NaN             NaN
# 100010                  NaN             NaN             NaN             NaN
# 100011                  NaN             NaN             NaN             NaN
# 100012                  NaN             NaN             NaN             NaN
#
#             FLOORSMIN_MODE  LANDAREA_MODE  LIVINGAPARTMENTS_MODE  \
# SK_ID_CURR
# 100002              0.1250         0.0377                  0.022
# 100003              0.3333         0.0128                  0.079
# 100004                 NaN            NaN                    NaN
# 100006                 NaN            NaN                    NaN
# 100007                 NaN            NaN                    NaN
# 100008                 NaN            NaN                    NaN
# 100009                 NaN            NaN                    NaN
# 100010                 NaN            NaN                    NaN
# 100011                 NaN            NaN                    NaN
# 100012                 NaN            NaN                    NaN
#
#             LIVINGAREA_MODE  NONLIVINGAPARTMENTS_MODE  NONLIVINGAREA_MODE  \
# SK_ID_CURR
# 100002               0.0198                       0.0                 0.0
# 100003               0.0554                       0.0                 0.0
# 100004                  NaN                       NaN                 NaN
# 100006                  NaN                       NaN                 NaN
# 100007                  NaN                       NaN                 NaN
# 100008                  NaN                       NaN                 NaN
# 100009                  NaN                       NaN                 NaN
# 100010                  NaN                       NaN                 NaN
# 100011                  NaN                       NaN                 NaN
# 100012                  NaN                       NaN                 NaN
#
#             APARTMENTS_MEDI  BASEMENTAREA_MEDI  YEARS_BEGINEXPLUATATION_MEDI  \
# SK_ID_CURR
# 100002               0.0250             0.0369                        0.9722
# 100003               0.0968             0.0529                        0.9851
# 100004                  NaN                NaN                           NaN
# 100006                  NaN                NaN                           NaN
# 100007                  NaN                NaN                           NaN
# 100008                  NaN                NaN                           NaN
# 100009                  NaN                NaN                           NaN
# 100010                  NaN                NaN                           NaN
# 100011                  NaN                NaN                           NaN
# 100012                  NaN                NaN                           NaN
#
#             YEARS_BUILD_MEDI  COMMONAREA_MEDI  ELEVATORS_MEDI  ENTRANCES_MEDI  \
# SK_ID_CURR
# 100002                0.6243           0.0144            0.00          0.0690
# 100003                0.7987           0.0608            0.08          0.0345
# 100004                   NaN              NaN             NaN             NaN
# 100006                   NaN              NaN             NaN             NaN
# 100007                   NaN              NaN             NaN             NaN
# 100008                   NaN              NaN             NaN             NaN
# 100009                   NaN              NaN             NaN             NaN
# 100010                   NaN              NaN             NaN             NaN
# 100011                   NaN              NaN             NaN             NaN
# 100012                   NaN              NaN             NaN             NaN
#
#             FLOORSMAX_MEDI  FLOORSMIN_MEDI  LANDAREA_MEDI  \
# SK_ID_CURR
# 100002              0.0833          0.1250         0.0375
# 100003              0.2917          0.3333         0.0132
# 100004                 NaN             NaN            NaN
# 100006                 NaN             NaN            NaN
# 100007                 NaN             NaN            NaN
# 100008                 NaN             NaN            NaN
# 100009                 NaN             NaN            NaN
# 100010                 NaN             NaN            NaN
# 100011                 NaN             NaN            NaN
# 100012                 NaN             NaN            NaN
#
#             LIVINGAPARTMENTS_MEDI  LIVINGAREA_MEDI  NONLIVINGAPARTMENTS_MEDI  \
# SK_ID_CURR
# 100002                     0.0205           0.0193                    0.0000
# 100003                     0.0787           0.0558                    0.0039
# 100004                        NaN              NaN                       NaN
# 100006                        NaN              NaN                       NaN
# 100007                        NaN              NaN                       NaN
# 100008                        NaN              NaN                       NaN
# 100009                        NaN              NaN                       NaN
# 100010                        NaN              NaN                       NaN
# 100011                        NaN              NaN                       NaN
# 100012                        NaN              NaN                       NaN
#
#             NONLIVINGAREA_MEDI FONDKAPREMONT_MODE  HOUSETYPE_MODE  \
# SK_ID_CURR
# 100002                    0.00   reg oper account  block of flats
# 100003                    0.01   reg oper account  block of flats
# 100004                     NaN                NaN             NaN
# 100006                     NaN                NaN             NaN
# 100007                     NaN                NaN             NaN
# 100008                     NaN                NaN             NaN
# 100009                     NaN                NaN             NaN
# 100010                     NaN                NaN             NaN
# 100011                     NaN                NaN             NaN
# 100012                     NaN                NaN             NaN
#
#             TOTALAREA_MODE WALLSMATERIAL_MODE EMERGENCYSTATE_MODE  \
# SK_ID_CURR
# 100002              0.0149       Stone, brick                  No
# 100003              0.0714              Block                  No
# 100004                 NaN                NaN                 NaN
# 100006                 NaN                NaN                 NaN
# 100007                 NaN                NaN                 NaN
# 100008                 NaN                NaN                 NaN
# 100009                 NaN                NaN                 NaN
# 100010                 NaN                NaN                 NaN
# 100011                 NaN                NaN                 NaN
# 100012                 NaN                NaN                 NaN
#
#             OBS_30_CNT_SOCIAL_CIRCLE  DEF_30_CNT_SOCIAL_CIRCLE  \
# SK_ID_CURR
# 100002                           2.0                       2.0
# 100003                           1.0                       0.0
# 100004                           0.0                       0.0
# 100006                           2.0                       0.0
# 100007                           0.0                       0.0
# 100008                           0.0                       0.0
# 100009                           1.0                       0.0
# 100010                           2.0                       0.0
# 100011                           1.0                       0.0
# 100012                           2.0                       0.0
#
#             OBS_60_CNT_SOCIAL_CIRCLE  DEF_60_CNT_SOCIAL_CIRCLE  \
# SK_ID_CURR
# 100002                           2.0                       2.0
# 100003                           1.0                       0.0
# 100004                           0.0                       0.0
# 100006                           2.0                       0.0
# 100007                           0.0                       0.0
# 100008                           0.0                       0.0
# 100009                           1.0                       0.0
# 100010                           2.0                       0.0
# 100011                           1.0                       0.0
# 100012                           2.0                       0.0
#
#             DAYS_LAST_PHONE_CHANGE  FLAG_DOCUMENT_2  FLAG_DOCUMENT_3  \
# SK_ID_CURR
# 100002                     -1134.0                0                1
# 100003                      -828.0                0                1
# 100004                      -815.0                0                0
# 100006                      -617.0                0                1
# 100007                     -1106.0                0                0
# 100008                     -2536.0                0                1
# 100009                     -1562.0                0                0
# 100010                     -1070.0                0                1
# 100011                         0.0                0                1
# 100012                     -1673.0                0                0
#
#             FLAG_DOCUMENT_4  FLAG_DOCUMENT_5  FLAG_DOCUMENT_6  \
# SK_ID_CURR
# 100002                    0                0                0
# 100003                    0                0                0
# 100004                    0                0                0
# 100006                    0                0                0
# 100007                    0                0                0
# 100008                    0                0                0
# 100009                    0                0                0
# 100010                    0                0                0
# 100011                    0                0                0
# 100012                    0                0                0
#
#             FLAG_DOCUMENT_7  FLAG_DOCUMENT_8  FLAG_DOCUMENT_9  \
# SK_ID_CURR
# 100002                    0                0                0
# 100003                    0                0                0
# 100004                    0                0                0
# 100006                    0                0                0
# 100007                    0                1                0
# 100008                    0                0                0
# 100009                    0                1                0
# 100010                    0                0                0
# 100011                    0                0                0
# 100012                    0                0                0
#
#             FLAG_DOCUMENT_10  FLAG_DOCUMENT_11  FLAG_DOCUMENT_12  \
# SK_ID_CURR
# 100002                     0                 0                 0
# 100003                     0                 0                 0
# 100004                     0                 0                 0
# 100006                     0                 0                 0
# 100007                     0                 0                 0
# 100008                     0                 0                 0
# 100009                     0                 0                 0
# 100010                     0                 0                 0
# 100011                     0                 0                 0
# 100012                     0                 0                 0
#
#             FLAG_DOCUMENT_13  FLAG_DOCUMENT_14  FLAG_DOCUMENT_15  \
# SK_ID_CURR
# 100002                     0                 0                 0
# 100003                     0                 0                 0
# 100004                     0                 0                 0
# 100006                     0                 0                 0
# 100007                     0                 0                 0
# 100008                     0                 0                 0
# 100009                     0                 1                 0
# 100010                     0                 0                 0
# 100011                     0                 0                 0
# 100012                     0                 0                 0
#
#             FLAG_DOCUMENT_16  FLAG_DOCUMENT_17  FLAG_DOCUMENT_18  \
# SK_ID_CURR
# 100002                     0                 0                 0
# 100003                     0                 0                 0
# 100004                     0                 0                 0
# 100006                     0                 0                 0
# 100007                     0                 0                 0
# 100008                     0                 0                 0
# 100009                     0                 0                 0
# 100010                     0                 0                 0
# 100011                     0                 0                 0
# 100012                     0                 0                 0
#
#             FLAG_DOCUMENT_19  FLAG_DOCUMENT_20  FLAG_DOCUMENT_21  \
# SK_ID_CURR
# 100002                     0                 0                 0
# 100003                     0                 0                 0
# 100004                     0                 0                 0
# 100006                     0                 0                 0
# 100007                     0                 0                 0
# 100008                     0                 0                 0
# 100009                     0                 0                 0
# 100010                     0                 0                 0
# 100011                     0                 0                 0
# 100012                     0                 0                 0
#
#             AMT_REQ_CREDIT_BUREAU_HOUR  AMT_REQ_CREDIT_BUREAU_DAY  \
# SK_ID_CURR
# 100002                             0.0                        0.0
# 100003                             0.0                        0.0
# 100004                             0.0                        0.0
# 100006                             NaN                        NaN
# 100007                             0.0                        0.0
# 100008                             0.0                        0.0
# 100009                             0.0                        0.0
# 100010                             0.0                        0.0
# 100011                             0.0                        0.0
# 100012                             NaN                        NaN
#
#             AMT_REQ_CREDIT_BUREAU_WEEK  AMT_REQ_CREDIT_BUREAU_MON  \
# SK_ID_CURR
# 100002                             0.0                        0.0
# 100003                             0.0                        0.0
# 100004                             0.0                        0.0
# 100006                             NaN                        NaN
# 100007                             0.0                        0.0
# 100008                             0.0                        0.0
# 100009                             0.0                        1.0
# 100010                             0.0                        0.0
# 100011                             0.0                        0.0
# 100012                             NaN                        NaN
#
#             AMT_REQ_CREDIT_BUREAU_QRT  AMT_REQ_CREDIT_BUREAU_YEAR    set  \
# SK_ID_CURR
# 100002                            0.0                         1.0  train
# 100003                            0.0                         0.0  train
# 100004                            0.0                         0.0  train
# 100006                            NaN                         NaN  train
# 100007                            0.0                         0.0  train
# 100008                            1.0                         1.0  train
# 100009                            1.0                         2.0  train
# 100010                            0.0                         0.0  train
# 100011                            0.0                         1.0  train
# 100012                            NaN                         NaN  train
#
#             COUNT(bureau)  MAX(bureau.AMT_ANNUITY)  \
# SK_ID_CURR
# 100002                  8                      0.0
# 100003                  4                      NaN
# 100004                  2                      NaN
# 100006                  0                      NaN
# 100007                  1                      NaN
# 100008                  3                      NaN
# 100009                 18                      NaN
# 100010                  2                      NaN
# 100011                  4                      NaN
# 100012                  0                      NaN
#
#             MAX(bureau.AMT_CREDIT_MAX_OVERDUE)  MAX(bureau.AMT_CREDIT_SUM)  \
# SK_ID_CURR
# 100002                                5043.645                    450000.0
# 100003                                   0.000                    810000.0
# 100004                                   0.000                     94537.8
# 100006                                     NaN                         NaN
# 100007                                   0.000                    146250.0
# 100008                                   0.000                    267606.0
# 100009                                   0.000                   1777500.0
# 100010                                     NaN                    675000.0
# 100011                               10147.230                    145242.0
# 100012                                     NaN                         NaN
#
#             MAX(bureau.AMT_CREDIT_SUM_DEBT)  MAX(bureau.AMT_CREDIT_SUM_LIMIT)  \
# SK_ID_CURR
# 100002                             245781.0                         31988.565
# 100003                                  0.0                        810000.000
# 100004                                  0.0                             0.000
# 100006                                  NaN                               NaN
# 100007                                  0.0                             0.000
# 100008                             240057.0                             0.000
# 100009                             557959.5                             0.000
# 100010                             348007.5                             0.000
# 100011                                  0.0                             0.000
# 100012                                  NaN                               NaN
#
#             MAX(bureau.AMT_CREDIT_SUM_OVERDUE)  \
# SK_ID_CURR
# 100002                                     0.0
# 100003                                     0.0
# 100004                                     0.0
# 100006                                     NaN
# 100007                                     0.0
# 100008                                     0.0
# 100009                                     0.0
# 100010                                     0.0
# 100011                                     0.0
# 100012                                     NaN
#
#             MAX(bureau.CNT_CREDIT_PROLONG)  MAX(bureau.CREDIT_DAY_OVERDUE)  \
# SK_ID_CURR
# 100002                                 0.0                             0.0
# 100003                                 0.0                             0.0
# 100004                                 0.0                             0.0
# 100006                                 NaN                             NaN
# 100007                                 0.0                             0.0
# 100008                                 0.0                             0.0
# 100009                                 0.0                             0.0
# 100010                                 0.0                             0.0
# 100011                                 0.0                             0.0
# 100012                                 NaN                             NaN
#
#             MAX(bureau.DAYS_CREDIT)  MAX(bureau.DAYS_CREDIT_ENDDATE)  \
# SK_ID_CURR
# 100002                       -103.0                            780.0
# 100003                       -606.0                           1216.0
# 100004                       -408.0                           -382.0
# 100006                          NaN                              NaN
# 100007                      -1149.0                           -783.0
# 100008                        -78.0                            471.0
# 100009                       -239.0                           1402.0
# 100010                      -1138.0                            689.0
# 100011                      -1309.0                           -860.0
# 100012                          NaN                              NaN
#
#             MAX(bureau.DAYS_CREDIT_UPDATE)  MAX(bureau.DAYS_ENDDATE_FACT)  \
# SK_ID_CURR
# 100002                                -7.0                          -36.0
# 100003                               -43.0                         -540.0
# 100004                              -382.0                         -382.0
# 100006                                 NaN                            NaN
# 100007                              -783.0                         -783.0
# 100008                               -16.0                         -790.0
# 100009                               -23.0                         -313.0
# 100010                               -18.0                        -1138.0
# 100011                              -965.0                         -968.0
# 100012                                 NaN                            NaN
#
#             MEAN(bureau.AMT_ANNUITY)  MEAN(bureau.AMT_CREDIT_MAX_OVERDUE)  \
# SK_ID_CURR
# 100002                           0.0                             1681.029
# 100003                           NaN                                0.000
# 100004                           NaN                                0.000
# 100006                           NaN                                  NaN
# 100007                           NaN                                0.000
# 100008                           NaN                                0.000
# 100009                           NaN                                0.000
# 100010                           NaN                                  NaN
# 100011                           NaN                             5073.615
# 100012                           NaN                                  NaN
#
#             MEAN(bureau.AMT_CREDIT_SUM)  MEAN(bureau.AMT_CREDIT_SUM_DEBT)  \
# SK_ID_CURR
# 100002                    108131.945625                      49156.200000
# 100003                    254350.125000                          0.000000
# 100004                     94518.900000                          0.000000
# 100006                              NaN                               NaN
# 100007                    146250.000000                          0.000000
# 100008                    156148.500000                      80019.000000
# 100009                    266711.750000                      76953.535714
# 100010                    495000.000000                     174003.750000
# 100011                    108807.075000                          0.000000
# 100012                              NaN                               NaN
#
#             MEAN(bureau.AMT_CREDIT_SUM_LIMIT)  \
# SK_ID_CURR
# 100002                             7997.14125
# 100003                           202500.00000
# 100004                                0.00000
# 100006                                    NaN
# 100007                                0.00000
# 100008                                0.00000
# 100009                                0.00000
# 100010                                0.00000
# 100011                                0.00000
# 100012                                    NaN
#
#             MEAN(bureau.AMT_CREDIT_SUM_OVERDUE)  \
# SK_ID_CURR
# 100002                                      0.0
# 100003                                      0.0
# 100004                                      0.0
# 100006                                      NaN
# 100007                                      0.0
# 100008                                      0.0
# 100009                                      0.0
# 100010                                      0.0
# 100011                                      0.0
# 100012                                      NaN
#
#             MEAN(bureau.CNT_CREDIT_PROLONG)  MEAN(bureau.CREDIT_DAY_OVERDUE)  \
# SK_ID_CURR
# 100002                                  0.0                              0.0
# 100003                                  0.0                              0.0
# 100004                                  0.0                              0.0
# 100006                                  NaN                              NaN
# 100007                                  0.0                              0.0
# 100008                                  0.0                              0.0
# 100009                                  0.0                              0.0
# 100010                                  0.0                              0.0
# 100011                                  0.0                              0.0
# 100012                                  NaN                              NaN
#
#             MEAN(bureau.DAYS_CREDIT)  MEAN(bureau.DAYS_CREDIT_ENDDATE)  \
# SK_ID_CURR
# 100002                   -874.000000                       -349.000000
# 100003                  -1400.750000                       -544.500000
# 100004                   -867.000000                       -488.500000
# 100006                           NaN                               NaN
# 100007                  -1149.000000                       -783.000000
# 100008                   -757.333333                       -391.333333
# 100009                  -1271.500000                       -794.937500
# 100010                  -1939.500000                       -119.500000
# 100011                  -1773.000000                      -1293.250000
# 100012                           NaN                               NaN
#
#             MEAN(bureau.DAYS_CREDIT_UPDATE)  MEAN(bureau.DAYS_ENDDATE_FACT)  \
# SK_ID_CURR
# 100002                          -499.875000                     -697.500000
# 100003                          -816.000000                    -1097.333333
# 100004                          -532.000000                     -532.500000
# 100006                                  NaN                             NaN
# 100007                          -783.000000                     -783.000000
# 100008                          -611.000000                     -909.000000
# 100009                          -851.611111                    -1108.500000
# 100010                          -578.000000                    -1138.000000
# 100011                         -1454.750000                    -1463.250000
# 100012                                  NaN                             NaN
#
#             MIN(bureau.AMT_ANNUITY)  MIN(bureau.AMT_CREDIT_MAX_OVERDUE)  \
# SK_ID_CURR
# 100002                          0.0                                 0.0
# 100003                          NaN                                 0.0
# 100004                          NaN                                 0.0
# 100006                          NaN                                 NaN
# 100007                          NaN                                 0.0
# 100008                          NaN                                 0.0
# 100009                          NaN                                 0.0
# 100010                          NaN                                 NaN
# 100011                          NaN                                 0.0
# 100012                          NaN                                 NaN
#
#             MIN(bureau.AMT_CREDIT_SUM)  MIN(bureau.AMT_CREDIT_SUM_DEBT)  \
# SK_ID_CURR
# 100002                             0.0                              0.0
# 100003                         22248.0                              0.0
# 100004                         94500.0                              0.0
# 100006                             NaN                              NaN
# ...
# 100008                                          NaN
# 100009                                          NaN
# 100010                                          NaN
# 100011                                       x-sell
# 100012                                          NaN
#
#             MODE(credit.previous.NAME_SELLER_INDUSTRY)  \
# SK_ID_CURR
# 100002                                             NaN
# 100003                                             NaN
# 100004                                             NaN
# 100006                                             XNA
# 100007                                             NaN
# 100008                                             NaN
# 100009                                             NaN
# 100010                                             NaN
# 100011                                             XNA
# 100012                                             NaN
#
#             MODE(credit.previous.NAME_TYPE_SUITE)  \
# SK_ID_CURR
# 100002                                        NaN
# 100003                                        NaN
# 100004                                        NaN
# 100006                              Unaccompanied
# 100007                                        NaN
# 100008                                        NaN
# 100009                                        NaN
# 100010                                        NaN
# 100011                                        NaN
# 100012                                        NaN
#
#             MODE(credit.previous.NAME_YIELD_GROUP)  \
# SK_ID_CURR
# 100002                                         NaN
# 100003                                         NaN
# 100004                                         NaN
# 100006                                         XNA
# 100007                                         NaN
# 100008                                         NaN
# 100009                                         NaN
# 100010                                         NaN
# 100011                                         XNA
# 100012                                         NaN
#
#             MODE(credit.previous.PRODUCT_COMBINATION)  \
# SK_ID_CURR
# 100002                                            NaN
# 100003                                            NaN
# 100004                                            NaN
# 100006                                    Card X-Sell
# 100007                                            NaN
# 100008                                            NaN
# 100009                                            NaN
# 100010                                            NaN
# 100011                                    Card X-Sell
# 100012                                            NaN
#
#             MODE(credit.previous.WEEKDAY_APPR_PROCESS_START)  \
# SK_ID_CURR
# 100002                                                   NaN
# 100003                                                   NaN
# 100004                                                   NaN
# 100006                                              THURSDAY
# 100007                                                   NaN
# 100008                                                   NaN
# 100009                                                   NaN
# 100010                                                   NaN
# 100011                                              SATURDAY
# 100012                                                   NaN
#
#             SUM(credit.previous.AMT_ANNUITY)  \
# SK_ID_CURR
# 100002                                   0.0
# 100003                                   0.0
# 100004                                   0.0
# 100006                               81000.0
# 100007                                   0.0
# 100008                                   0.0
# 100009                                   0.0
# 100010                                   0.0
# 100011                              666000.0
# 100012                                   0.0
#
#             SUM(credit.previous.AMT_APPLICATION)  \
# SK_ID_CURR
# 100002                                       0.0
# 100003                                       0.0
# 100004                                       0.0
# 100006                                 1620000.0
# 100007                                       0.0
# 100008                                       0.0
# 100009                                       0.0
# 100010                                       0.0
# 100011                                       0.0
# 100012                                       0.0
#
#             SUM(credit.previous.AMT_CREDIT)  \
# SK_ID_CURR
# 100002                                  0.0
# 100003                                  0.0
# 100004                                  0.0
# 100006                            1620000.0
# 100007                                  0.0
# 100008                                  0.0
# 100009                                  0.0
# 100010                                  0.0
# 100011                           13320000.0
# 100012                                  0.0
#
#             SUM(credit.previous.AMT_DOWN_PAYMENT)  \
# SK_ID_CURR
# 100002                                        0.0
# 100003                                        0.0
# 100004                                        0.0
# 100006                                        0.0
# 100007                                        0.0
# 100008                                        0.0
# 100009                                        0.0
# 100010                                        0.0
# 100011                                        0.0
# 100012                                        0.0
#
#             SUM(credit.previous.AMT_GOODS_PRICE)  \
# SK_ID_CURR
# 100002                                       0.0
# 100003                                       0.0
# 100004                                       0.0
# 100006                                 1620000.0
# 100007                                       0.0
# 100008                                       0.0
# 100009                                       0.0
# 100010                                       0.0
# 100011                                       0.0
# 100012                                       0.0
#
#             SUM(credit.previous.CNT_PAYMENT)  \
# SK_ID_CURR
# 100002                                   0.0
# 100003                                   0.0
# 100004                                   0.0
# 100006                                   0.0
# 100007                                   0.0
# 100008                                   0.0
# 100009                                   0.0
# 100010                                   0.0
# 100011                                   0.0
# 100012                                   0.0
#
#             SUM(credit.previous.DAYS_DECISION)  \
# SK_ID_CURR
# 100002                                     0.0
# 100003                                     0.0
# 100004                                     0.0
# 100006                                 -1086.0
# 100007                                     0.0
# 100008                                     0.0
# 100009                                     0.0
# 100010                                     0.0
# 100011                               -168646.0
# 100012                                     0.0
#
#             SUM(credit.previous.DAYS_FIRST_DRAWING)  \
# SK_ID_CURR
# 100002                                          0.0
# 100003                                          0.0
# 100004                                          0.0
# 100006                                    2191458.0
# 100007                                          0.0
# 100008                                          0.0
# 100009                                          0.0
# 100010                                          0.0
# 100011                                    -168498.0
# 100012                                          0.0
#
#             SUM(credit.previous.DAYS_FIRST_DUE)  \
# SK_ID_CURR
# 100002                                      0.0
# 100003                                      0.0
# 100004                                      0.0
# 100006                                2191458.0
# 100007                                      0.0
# 100008                                      0.0
# 100009                                      0.0
# 100010                                      0.0
# 100011                                -164946.0
# 100012                                      0.0
#
#             SUM(credit.previous.DAYS_LAST_DUE)  \
# SK_ID_CURR
# 100002                                     0.0
# 100003                                     0.0
# 100004                                     0.0
# 100006                               2191458.0
# 100007                                     0.0
# 100008                                     0.0
# 100009                                     0.0
# 100010                                     0.0
# 100011                                -93018.0
# 100012                                     0.0
#
#             SUM(credit.previous.DAYS_LAST_DUE_1ST_VERSION)  \
# SK_ID_CURR
# 100002                                                 0.0
# 100003                                                 0.0
# 100004                                                 0.0
# 100006                                           2191458.0
# 100007                                                 0.0
# 100008                                                 0.0
# 100009                                                 0.0
# 100010                                                 0.0
# 100011                                          27027982.0
# 100012                                                 0.0
#
#            SUM(credit.previous.DAYS_TERMINATION)  \
# SK_ID_CURR
# 100002                                       0.0
# 100003                                       0.0
# 100004                                       0.0
# 100006                                 2191458.0
# 100007                                       0.0
# 100008                                       0.0
# 100009                                       0.0
# 100010                                       0.0
# 100011                                27027982.0
# 100012                                       0.0
#
#            SUM(credit.previous.HOUR_APPR_PROCESS_START)  \
# SK_ID_CURR
# 100002                                              0.0
# 100003                                              0.0
# 100004                                              0.0
# 100006                                             90.0
# 100007                                              0.0
# 100008                                              0.0
# 100009                                              0.0
# 100010                                              0.0
# 100011                                            740.0
# 100012                                              0.0
#
#            SUM(credit.previous.NFLAG_INSURED_ON_APPROVAL)  \
# SK_ID_CURR
# 100002                                                0.0
# 100003                                                0.0
# 100004                                                0.0
# 100006                                                0.0
# 100007                                                0.0
# 100008                                                0.0
# 100009                                                0.0
# 100010                                                0.0
# 100011                                                0.0
# 100012                                                0.0
#
#            SUM(credit.previous.NFLAG_LAST_APPL_IN_DAY)  \
# SK_ID_CURR
# 100002                                             0.0
# 100003                                             0.0
# 100004                                             0.0
# 100006                                             6.0
# 100007                                             0.0
# 100008                                             0.0
# 100009                                             0.0
# 100010                                             0.0
# 100011                                            74.0
# 100012                                             0.0
#
#            SUM(credit.previous.RATE_DOWN_PAYMENT)  \
# SK_ID_CURR
# 100002                                        0.0
# 100003                                        0.0
# 100004                                        0.0
# 100006                                        0.0
# 100007                                        0.0
# 100008                                        0.0
# 100009                                        0.0
# 100010                                        0.0
# 100011                                        0.0
# 100012                                        0.0
#
#            SUM(credit.previous.RATE_INTEREST_PRIMARY)  \
# SK_ID_CURR
# 100002                                            0.0
# 100003                                            0.0
# 100004                                            0.0
# 100006                                            0.0
# 100007                                            0.0
# 100008                                            0.0
# 100009                                            0.0
# 100010                                            0.0
# 100011                                            0.0
# 100012                                            0.0
#
#            SUM(credit.previous.RATE_INTEREST_PRIVILEGED)  \
# SK_ID_CURR
# 100002                                               0.0
# 100003                                               0.0
# 100004                                               0.0
# 100006                                               0.0
# 100007                                               0.0
# 100008                                               0.0
# 100009                                               0.0
# 100010                                               0.0
# 100011                                               0.0
# 100012                                               0.0
#
#            SUM(credit.previous.SELLERPLACE_AREA)
# SK_ID_CURR
# 100002                                       0.0
# 100003                                       0.0
# 100004                                       0.0
# 100006                                      -6.0
# 100007                                       0.0
# 100008                                       0.0
# 100009                                       0.0
# 100010                                       0.0
# 100011                                       0.0
# 100012                                       0.0
#
# [10 rows x 1211 columns]

# %%
correlations = feature_matrix_spec.corr()
correlations.index.name = 'Variable'
correlations.head()
# Out:
#                     TARGET  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  \
# Variable
# TARGET            1.000000      0.025307         -0.007118    0.008316
# CNT_CHILDREN      0.025307      1.000000          0.045813    0.002410
# AMT_INCOME_TOTAL -0.007118      0.045813          1.000000    0.413117
# AMT_CREDIT        0.008316      0.002410          0.413117    1.000000
# AMT_ANNUITY       0.024608      0.023826          0.486044    0.771190
#
#                   AMT_ANNUITY  AMT_GOODS_PRICE  REGION_POPULATION_RELATIVE  \
# Variable
# TARGET               0.024608        -0.001968                    0.014177
# CNT_CHILDREN         0.023826        -0.001697                   -0.029300
# AMT_INCOME_TOTAL     0.486044         0.418351                    0.209621
# AMT_CREDIT           0.771190         0.986906                    0.101144
# AMT_ANNUITY          1.000000         0.773800                    0.116639
#
#                   DAYS_BIRTH  DAYS_EMPLOYED  DAYS_REGISTRATION  \
# Variable
# TARGET              0.082907      -0.010218           0.017294
# CNT_CHILDREN        0.307422      -0.238034           0.181558
# AMT_INCOME_TOTAL    0.070745      -0.197548           0.083315
# AMT_CREDIT         -0.061776      -0.112875           0.021207
# AMT_ANNUITY         0.034653      -0.152037           0.055317
#
#                   DAYS_ID_PUBLISH  OWN_CAR_AGE  FLAG_MOBIL  FLAG_EMP_PHONE  \
# Variable
# TARGET                   0.055585    -0.042166         NaN        0.011991
# CNT_CHILDREN            -0.029758     0.073046         NaN        0.239114
# AMT_INCOME_TOTAL         0.047704    -0.197711         NaN        0.196764
# AMT_CREDIT               0.000342    -0.115455         NaN        0.111235
# AMT_ANNUITY              0.017764    -0.121954         NaN        0.151380
#
#                   FLAG_WORK_PHONE  FLAG_CONT_MOBILE  FLAG_PHONE  FLAG_EMAIL  \
# Variable
# TARGET                   0.049613          0.015034   -0.015172   -0.007614
# CNT_CHILDREN             0.018667          0.010599   -0.052892    0.067123
# AMT_INCOME_TOTAL        -0.042697          0.019151    0.014203    0.100260
# AMT_CREDIT              -0.065063          0.047616    0.024988    0.035303
# AMT_ANNUITY             -0.086996          0.060842    0.006076    0.087160
#
#                   CNT_FAM_MEMBERS  REGION_RATING_CLIENT  \
# Variable
# TARGET                  -0.004360              0.048279
# CNT_CHILDREN             0.885509              0.009566
# AMT_INCOME_TOTAL         0.053982             -0.239570
# AMT_CREDIT               0.072313             -0.101845
# AMT_ANNUITY              0.086728             -0.131282
#
#                   REGION_RATING_CLIENT_W_CITY  HOUR_APPR_PROCESS_START  \
# Variable
# TARGET                               0.047879                -0.047849
# CNT_CHILDREN                         0.020860                -0.045242
# AMT_INCOME_TOTAL                    -0.250599                 0.049676
# AMT_CREDIT                          -0.110144                 0.036429
# AMT_ANNUITY                         -0.131239                 0.018041
#
#                   REG_REGION_NOT_LIVE_REGION  REG_REGION_NOT_WORK_REGION  \
# Variable
# TARGET                              0.051329                    0.034044
# CNT_CHILDREN                       -0.000808                    0.021506
# AMT_INCOME_TOTAL                    0.085630                    0.182124
# AMT_CREDIT                          0.001710                    0.044024
# AMT_ANNUITY                         0.035167                    0.083555
#
#                   LIVE_REGION_NOT_WORK_REGION  REG_CITY_NOT_LIVE_CITY  \
# Variable
# TARGET                               0.035034                0.015907
# CNT_CHILDREN                         0.017523                0.003878
# AMT_INCOME_TOTAL                     0.186722                0.008247
# AMT_CREDIT                           0.048567               -0.016529
# AMT_ANNUITY                          0.090200                0.012765
#
#                   REG_CITY_NOT_WORK_CITY  LIVE_CITY_NOT_WORK_CITY  \
# Variable
# TARGET                          0.049930                 0.024858
# CNT_CHILDREN                    0.041974                 0.050099
# AMT_INCOME_TOTAL                0.030689                 0.040487
# AMT_CREDIT                     -0.022943                -0.010616
# AMT_ANNUITY                     0.001281                 0.005487
#
#                   EXT_SOURCE_1  EXT_SOURCE_2  EXT_SOURCE_3  APARTMENTS_AVG  \
# Variable
# TARGET               -0.126033     -0.195159     -0.236305       -0.029215
# CNT_CHILDREN         -0.093556     -0.004368     -0.026952       -0.065924
# AMT_INCOME_TOTAL      0.096639      0.143326     -0.094971        0.112432
# AMT_CREDIT            0.177788      0.098633      0.041416        0.077818
# AMT_ANNUITY           0.139502      0.097592      0.014131        0.106271
#
#                   BASEMENTAREA_AVG  YEARS_BEGINEXPLUATATION_AVG  \
# Variable
# TARGET                   -0.015604                    -0.109070
# CNT_CHILDREN             -0.070570                     0.017230
# AMT_INCOME_TOTAL          0.081631                     0.023684
# AMT_CREDIT                0.042426                     0.017666
# AMT_ANNUITY               0.071934                     0.025763
#
#                   YEARS_BUILD_AVG  COMMONAREA_AVG  ELEVATORS_AVG  \
# Variable
# TARGET                   0.056153        0.064366      -0.011130
# CNT_CHILDREN             0.034572       -0.008730      -0.016255
# AMT_INCOME_TOTAL        -0.046492        0.046173       0.168586
# AMT_CREDIT               0.059536        0.017366       0.129153
# AMT_ANNUITY              0.060618        0.052524       0.138481
#
#                   ENTRANCES_AVG  FLOORSMAX_AVG  FLOORSMIN_AVG  LANDAREA_AVG  \
# Variable
# TARGET                -0.029747      -0.011112      -0.040934     -0.056691
# CNT_CHILDREN          -0.054717      -0.025093      -0.027714     -0.018488
# AMT_INCOME_TOTAL       0.040789       0.195923       0.057309      0.020694
# AMT_CREDIT             0.049621       0.132583       0.045633      0.023172
# AMT_ANNUITY            0.073604       0.157164       0.071758      0.034023
#
#                   LIVINGAPARTMENTS_AVG  LIVINGAREA_AVG  \
# Variable
# TARGET                       -0.030848       -0.013003
# CNT_CHILDREN                 -0.039941       -0.067090
# AMT_INCOME_TOTAL              0.070974        0.148389
# AMT_CREDIT                    0.007228        0.121674
# AMT_ANNUITY                   0.059086        0.131265
#
#                   NONLIVINGAPARTMENTS_AVG  NONLIVINGAREA_AVG  APARTMENTS_MODE  \
# Variable
# TARGET                          -0.052668          -0.037253        -0.021345
# CNT_CHILDREN                    -0.030822          -0.000459        -0.072033
# AMT_INCOME_TOTAL                 0.017817           0.056784         0.095101
# AMT_CREDIT                       0.016174           0.047947         0.065263
# AMT_ANNUITY                      0.100185           0.034112         0.093674
#
#                   BASEMENTAREA_MODE  YEARS_BEGINEXPLUATATION_MODE  \
# Variable
# TARGET                    -0.004340                     -0.098599
# CNT_CHILDREN              -0.083808                      0.011338
# AMT_INCOME_TOTAL           0.069640                      0.024721
# AMT_CREDIT                 0.040716                      0.018446
# AMT_ANNUITY                0.071809                      0.025140
#
#                   YEARS_BUILD_MODE  COMMONAREA_MODE  ELEVATORS_MODE  \
# Variable
# TARGET                    0.061698         0.073427       -0.008370
# CNT_CHILDREN              0.041007        -0.007762       -0.020144
# AMT_INCOME_TOTAL         -0.056256         0.043383        0.163157
# AMT_CREDIT                0.062692         0.013896        0.125638
# AMT_ANNUITY               0.059344         0.051346        0.134266
#
#                   ENTRANCES_MODE  FLOORSMAX_MODE  FLOORSMIN_MODE  \
# Variable
# TARGET                 -0.016815       -0.012355       -0.034286
# CNT_CHILDREN           -0.057992       -0.026414       -0.026942
# AMT_INCOME_TOTAL        0.027727        0.186935        0.040499
# AMT_CREDIT              0.044767        0.131867        0.046467
# AMT_ANNUITY             0.064715        0.154152        0.069058
#
#                   LANDAREA_MODE  LIVINGAPARTMENTS_MODE  LIVINGAREA_MODE  \
# Variable
# TARGET                -0.048706              -0.014392        -0.000051
# CNT_CHILDREN          -0.022364              -0.046401        -0.074517
# AMT_INCOME_TOTAL       0.022189               0.050309         0.132725
# AMT_CREDIT             0.025011              -0.008129         0.113048
# AMT_ANNUITY            0.033197               0.046835         0.118934
#
#                   NONLIVINGAPARTMENTS_MODE  NONLIVINGAREA_MODE  \
# Variable
# TARGET                           -0.056173           -0.030958
# CNT_CHILDREN                     -0.036590            0.000339
# AMT_INCOME_TOTAL                  0.019683            0.043688
# AMT_CREDIT                        0.010633            0.042370
# AMT_ANNUITY                       0.105376            0.028335
#
#                   APARTMENTS_MEDI  BASEMENTAREA_MEDI  \
# Variable
# TARGET                  -0.027935          -0.014363
# CNT_CHILDREN            -0.064934          -0.072468
# AMT_INCOME_TOTAL         0.110014           0.081838
# AMT_CREDIT               0.075978           0.043931
# AMT_ANNUITY              0.103575           0.072185
#
#                   YEARS_BEGINEXPLUATATION_MEDI  YEARS_BUILD_MEDI  \
# Variable
# TARGET                               -0.134431          0.056321
# CNT_CHILDREN                          0.013269          0.036506
# AMT_INCOME_TOTAL                      0.018118         -0.052045
# AMT_CREDIT                            0.011914          0.056793
# AMT_ANNUITY                           0.018603          0.058242
#
#                   COMMONAREA_MEDI  ELEVATORS_MEDI  ENTRANCES_MEDI  \
# Variable
# TARGET                   0.064574       -0.009995       -0.029321
# CNT_CHILDREN            -0.010290       -0.017613       -0.055433
# AMT_INCOME_TOTAL         0.047315        0.168640        0.038567
# AMT_CREDIT               0.015819        0.129943        0.048312
# AMT_ANNUITY              0.052113        0.138272        0.071465
#
#                   FLOORSMAX_MEDI  FLOORSMIN_MEDI  LANDAREA_MEDI  \
# Variable
# TARGET                 -0.010559       -0.040320      -0.055167
# CNT_CHILDREN           -0.024692       -0.030177      -0.019695
# AMT_INCOME_TOTAL        0.193086        0.053080       0.022009
# AMT_CREDIT              0.129490        0.044643       0.023993
# AMT_ANNUITY             0.154051        0.067846       0.033895
#
#                   LIVINGAPARTMENTS_MEDI  LIVINGAREA_MEDI  \
# Variable
# TARGET                        -0.028617        -0.012387
# CNT_CHILDREN                  -0.039782        -0.067458
# AMT_INCOME_TOTAL               0.065579         0.146038
# AMT_CREDIT                     0.005025         0.121731
# AMT_ANNUITY                    0.053726         0.128919
#
#                   NONLIVINGAPARTMENTS_MEDI  NONLIVINGAREA_MEDI  \
# Variable
# TARGET                           -0.053457           -0.036495
# CNT_CHILDREN                     -0.031380           -0.001045
# AMT_INCOME_TOTAL                  0.019529            0.055849
# AMT_CREDIT                        0.015454            0.047056
# AMT_ANNUITY                       0.101443            0.034064
#
#                   TOTALAREA_MODE  OBS_30_CNT_SOCIAL_CIRCLE  \
# Variable
# TARGET                 -0.030899                  0.007829
# CNT_CHILDREN           -0.066014                 -0.030084
# AMT_INCOME_TOTAL        0.161824                 -0.072633
# AMT_CREDIT              0.124838                 -0.010235
# AMT_ANNUITY             0.127227                 -0.026520
#
#                   DEF_30_CNT_SOCIAL_CIRCLE  OBS_60_CNT_SOCIAL_CIRCLE  \
# Variable
# TARGET                            0.021366                  0.008250
# CNT_CHILDREN                     -0.006989                 -0.029431
# AMT_INCOME_TOTAL                 -0.086596                 -0.073928
# AMT_CREDIT                       -0.006997                 -0.010286
# AMT_ANNUITY                      -0.035034                 -0.026314
#
#                   DEF_60_CNT_SOCIAL_CIRCLE  DAYS_LAST_PHONE_CHANGE  \
# Variable
# TARGET                            0.010869                0.074258
# CNT_CHILDREN                      0.002198                0.030875
# AMT_INCOME_TOTAL                 -0.091653               -0.022675
# AMT_CREDIT                       -0.009675               -0.039554
# AMT_ANNUITY                      -0.039257               -0.011959
#
#                   FLAG_DOCUMENT_2  FLAG_DOCUMENT_3  FLAG_DOCUMENT_4  \
# Variable
# TARGET                        NaN         0.020757              NaN
# CNT_CHILDREN                  NaN         0.075308              NaN
# AMT_INCOME_TOTAL              NaN        -0.084747              NaN
# AMT_CREDIT                    NaN         0.036730              NaN
# AMT_ANNUITY                   NaN         0.049778              NaN
#
#                   FLAG_DOCUMENT_5  FLAG_DOCUMENT_6  FLAG_DOCUMENT_7  \
# Variable
# TARGET                  -0.036041         0.006071              NaN
# CNT_CHILDREN            -0.028321        -0.139038              NaN
# AMT_INCOME_TOTAL         0.047497        -0.103184              NaN
# AMT_CREDIT               0.029065        -0.071452              NaN
# AMT_ANNUITY              0.019098        -0.100112              NaN
#
#                   FLAG_DOCUMENT_8  FLAG_DOCUMENT_9  FLAG_DOCUMENT_10  \
# Variable
# TARGET                   0.000786        -0.017368               NaN
# CNT_CHILDREN             0.027220        -0.015005               NaN
# AMT_INCOME_TOTAL         0.189113         0.005202               NaN
# AMT_CREDIT               0.062196         0.025645               NaN
# AMT_ANNUITY              0.120242         0.024500               NaN
#
#                   FLAG_DOCUMENT_11  FLAG_DOCUMENT_12  FLAG_DOCUMENT_13  \
# Variable
# TARGET                   -0.015034               NaN         -0.012269
# CNT_CHILDREN             -0.029025               NaN          0.003361
# AMT_INCOME_TOTAL         -0.011415               NaN          0.034467
# AMT_CREDIT               -0.013065               NaN          0.049546
# AMT_ANNUITY              -0.027785               NaN          0.033997
#
#                   FLAG_DOCUMENT_14  FLAG_DOCUMENT_15  FLAG_DOCUMENT_16  \
# Variable
# TARGET                   -0.012269         -0.008671          0.011844
# CNT_CHILDREN              0.003361          0.017719          0.017256
# AMT_INCOME_TOTAL         -0.005666          0.013796         -0.007405
# AMT_CREDIT                0.071769          0.023716          0.014429
# AMT_ANNUITY               0.035508         -0.004347         -0.024261
#
#                   FLAG_DOCUMENT_17  FLAG_DOCUMENT_18  FLAG_DOCUMENT_19  \
# Variable
# TARGET                         NaN          0.091700               NaN
# CNT_CHILDREN                   NaN         -0.019260               NaN
# AMT_INCOME_TOTAL               NaN         -0.026222               NaN
# AMT_CREDIT                     NaN         -0.005706               NaN
# AMT_ANNUITY                    NaN         -0.027767               NaN
#
#                   FLAG_DOCUMENT_20  FLAG_DOCUMENT_21  \
# Variable
# TARGET                         NaN               NaN
# CNT_CHILDREN                   NaN               NaN
# AMT_INCOME_TOTAL               NaN               NaN
# AMT_CREDIT                     NaN               NaN
# AMT_ANNUITY                    NaN               NaN
#
#                   AMT_REQ_CREDIT_BUREAU_HOUR  AMT_REQ_CREDIT_BUREAU_DAY  \
# Variable
# TARGET                              0.021530                   0.022899
# CNT_CHILDREN                        0.022527                  -0.000227
# AMT_INCOME_TOTAL                   -0.019594                  -0.028114
# AMT_CREDIT                         -0.019934                   0.004833
# AMT_ANNUITY                        -0.005877                  -0.015092
#
#                   AMT_REQ_CREDIT_BUREAU_WEEK  AMT_REQ_CREDIT_BUREAU_MON  \
# Variable
# TARGET                             -0.025546                   0.057558
# CNT_CHILDREN                        0.028033                   0.012992
# AMT_INCOME_TOTAL                   -0.009641                   0.076547
# AMT_CREDIT                         -0.003046                   0.105442
# AMT_ANNUITY                        -0.004661                   0.034694
#
#                   AMT_REQ_CREDIT_BUREAU_QRT  AMT_REQ_CREDIT_BUREAU_YEAR  \
# Variable
# TARGET                            -0.029428                   -0.036360
# CNT_CHILDREN                       0.004532                   -0.044675
# AMT_INCOME_TOTAL                   0.013647                    0.021565
# AMT_CREDIT                        -0.041711                   -0.018648
# AMT_ANNUITY                        0.014224                   -0.006722
#
#                   COUNT(bureau)  MAX(bureau.AMT_ANNUITY)  \
# Variable
# TARGET                -0.020895                -0.167218
# CNT_CHILDREN           0.022036                 0.103281
# AMT_INCOME_TOTAL       0.010856                 0.358257
# AMT_CREDIT             0.028365                 0.167047
# AMT_ANNUITY           -0.031036                 0.049467
#
#                   MAX(bureau.AMT_CREDIT_MAX_OVERDUE)  \
# Variable
# TARGET                                     -0.015124
# CNT_CHILDREN                               -0.036333
# AMT_INCOME_TOTAL                            0.260192
# AMT_CREDIT                                  0.028760
# AMT_ANNUITY                                 0.089140
#
#                   MAX(bureau.AMT_CREDIT_SUM)  MAX(bureau.AMT_CREDIT_SUM_DEBT)  \
# Variable
# TARGET                              0.004779                         0.016567
# CNT_CHILDREN                        0.140165                         0.144759
# AMT_INCOME_TOTAL                    0.226027                         0.168319
# AMT_CREDIT                          0.094626                         0.040016
# AMT_ANNUITY                         0.030665                        -0.051040
#
#                   MAX(bureau.AMT_CREDIT_SUM_LIMIT)  \
# Variable
# TARGET                                   -0.026178
# CNT_CHILDREN                             -0.076262
# AMT_INCOME_TOTAL                          0.098320
# AMT_CREDIT                                0.179915
# AMT_ANNUITY                               0.058872
#
#                   MAX(bureau.AMT_CREDIT_SUM_OVERDUE)  \
# Variable
# TARGET                                     -0.022513
# CNT_CHILDREN                               -0.045369
# AMT_INCOME_TOTAL                           -0.029917
# AMT_CREDIT                                  0.040857
# AMT_ANNUITY                                 0.008470
#
#                   MAX(bureau.CNT_CREDIT_PROLONG)  \
# Variable
# TARGET                                 -0.036403
# CNT_CHILDREN                            0.178599
# AMT_INCOME_TOTAL                        0.078805
# AMT_CREDIT                              0.020219
# AMT_ANNUITY                            -0.002978
#
#                   MAX(bureau.CREDIT_DAY_OVERDUE)  MAX(bureau.DAYS_CREDIT)  \
# Variable
# TARGET                                 -0.021771                 0.037539
# CNT_CHILDREN                           -0.043875                 0.040892
# AMT_INCOME_TOTAL                       -0.046902                 0.074339
# AMT_CREDIT                             -0.002964                 0.052107
# AMT_ANNUITY                            -0.041334                 0.003938
#
#                   MAX(bureau.DAYS_CREDIT_ENDDATE)  \
# Variable
# TARGET                                   0.178670
# CNT_CHILDREN                             0.125895
# AMT_INCOME_TOTAL                         0.125532
# AMT_CREDIT                               0.036804
# AMT_ANNUITY                             -0.011896
#
#                   MAX(bureau.DAYS_CREDIT_UPDATE)  \
# Variable
# TARGET                                  0.009785
# CNT_CHILDREN                            0.042858
# AMT_INCOME_TOTAL                        0.069493
# AMT_CREDIT                              0.041338
# AMT_ANNUITY                             0.048454
#
#                   MAX(bureau.DAYS_ENDDATE_FACT)  MEAN(bureau.AMT_ANNUITY)  \
# Variable
# TARGET                                 0.040673                 -0.104146
# CNT_CHILDREN                           0.014582                 -0.043686
# AMT_INCOME_TOTAL                      -0.031229                  0.220786
# AMT_CREDIT                            -0.056872                  0.127373
# AMT_ANNUITY                            0.032164                  0.018540
#
#                   MEAN(bureau.AMT_CREDIT_MAX_OVERDUE)  \
# Variable
# TARGET                                       0.009055
# CNT_CHILDREN                                -0.122330
# AMT_INCOME_TOTAL                             0.216736
# AMT_CREDIT                                   0.080421
# AMT_ANNUITY                                  0.229749
#
#                   MEAN(bureau.AMT_CREDIT_SUM)  \
# Variable
# TARGET                              -0.007068
# CNT_CHILDREN                         0.079370
# AMT_INCOME_TOTAL                     0.097448
# AMT_CREDIT                           0.053621
# AMT_ANNUITY                          0.011742
#
#                   MEAN(bureau.AMT_CREDIT_SUM_DEBT)  \
# Variable
# TARGET                                    0.006343
# CNT_CHILDREN                              0.099424
# AMT_INCOME_TOTAL                          0.026056
# AMT_CREDIT                               -0.003721
# AMT_ANNUITY                              -0.060912
#
#                   MEAN(bureau.AMT_CREDIT_SUM_LIMIT)  \
# Variable
# TARGET                                     0.022512
# CNT_CHILDREN                              -0.076319
# AMT_INCOME_TOTAL                           0.080146
# AMT_CREDIT                                 0.173576
# AMT_ANNUITY                                0.059501
#
#                   MEAN(bureau.AMT_CREDIT_SUM_OVERDUE)  \
# Variable
# TARGET                                      -0.021190
# CNT_CHILDREN                                -0.042705
# AMT_INCOME_TOTAL                            -0.026963
# AMT_CREDIT                                   0.041288
# AMT_ANNUITY                                  0.011271
#
#                   MEAN(bureau.CNT_CREDIT_PROLONG)  \
# Variable
# TARGET                                  -0.035973
# CNT_CHILDREN                             0.162963
# AMT_INCOME_TOTAL                         0.083958
# AMT_CREDIT                               0.026621
# AMT_ANNUITY                              0.001661
#
#                   MEAN(bureau.CREDIT_DAY_OVERDUE)  MEAN(bureau.DAYS_CREDIT)  \
# Variable
# TARGET                                  -0.025183                  0.124977
# CNT_CHILDREN                            -0.050743                 -0.073081
# AMT_INCOME_TOTAL                        -0.050700                 -0.043137
# AMT_CREDIT                               0.004949                 -0.106895
# AMT_ANNUITY                             -0.038037                 -0.058025
#
#                   MEAN(bureau.DAYS_CREDIT_ENDDATE)  \
# Variable
# TARGET                                    0.342626
# CNT_CHILDREN                              0.038126
# AMT_INCOME_TOTAL                          0.045825
# AMT_CREDIT                               -0.000546
# AMT_ANNUITY                               0.015810
#
#                   MEAN(bureau.DAYS_CREDIT_UPDATE)  \
# Variable
# TARGET                                   0.094903
# CNT_CHILDREN                            -0.078314
# AMT_INCOME_TOTAL                         0.015016
# AMT_CREDIT                              -0.053070
# AMT_ANNUITY                             -0.012084
#
#                   MEAN(bureau.DAYS_ENDDATE_FACT)  MIN(bureau.AMT_ANNUITY)  \
# Variable
# TARGET                                  0.050087                -0.084769
# CNT_CHILDREN                           -0.062717                -0.082609
# AMT_INCOME_TOTAL                       -0.081175                 0.156692
# AMT_CREDIT                             -0.128519                 0.134758
# AMT_ANNUITY                            -0.071413                 0.038124
#
#                   MIN(bureau.AMT_CREDIT_MAX_OVERDUE)  \
# Variable
# TARGET                                      0.004150
# CNT_CHILDREN                               -0.072921
# AMT_INCOME_TOTAL                            0.024036
# AMT_CREDIT                                  0.039540
# AMT_ANNUITY                                 0.299464
#
#                   MIN(bureau.AMT_CREDIT_SUM)  MIN(bureau.AMT_CREDIT_SUM_DEBT)  \
# Variable
# TARGET                             -0.014460                        -0.014205
# CNT_CHILDREN                        0.060544                         0.089927
# AMT_INCOME_TOTAL                   -0.016263                        -0.036334
# AMT_CREDIT                          0.011649                        -0.023969
# AMT_ANNUITY                        -0.012863                        -0.058139
#
#                   MIN(bureau.AMT_CREDIT_SUM_LIMIT)  \
# Variable
# TARGET                                    0.370006
# CNT_CHILDREN                              0.068722
# AMT_INCOME_TOTAL                         -0.006951
# AMT_CREDIT                                0.031299
# AMT_ANNUITY                               0.028288
#
#                   MIN(bureau.AMT_CREDIT_SUM_OVERDUE)  \
# Variable
# TARGET                                           NaN
# CNT_CHILDREN                                     NaN
# AMT_INCOME_TOTAL                                 NaN
# AMT_CREDIT                                       NaN
# AMT_ANNUITY                                      NaN
#
#                   MIN(bureau.CNT_CREDIT_PROLONG)  \
# Variable
# TARGET                                       NaN
# CNT_CHILDREN                                 NaN
# AMT_INCOME_TOTAL                             NaN
# AMT_CREDIT                                   NaN
# AMT_ANNUITY                                  NaN
#
#                   MIN(bureau.CREDIT_DAY_OVERDUE)  MIN(bureau.DAYS_CREDIT)  \
# Variable
# TARGET                                       NaN                 0.147881
# CNT_CHILDREN                                 NaN                -0.095704
# AMT_INCOME_TOTAL                             NaN                -0.077777
# AMT_CREDIT                                   NaN                -0.148279
# AMT_ANNUITY                                  NaN                -0.038898
#
#                   MIN(bureau.DAYS_CREDIT_ENDDATE)  \
# Variable
# TARGET                                   0.323582
# CNT_CHILDREN                            -0.075394
# AMT_INCOME_TOTAL                        -0.053362
# AMT_CREDIT                              -0.094369
# AMT_ANNUITY                             -0.042323
#
#                   MIN(bureau.DAYS_CREDIT_UPDATE)  \
# Variable
# TARGET                                  0.115652
# CNT_CHILDREN                           -0.152599
# AMT_INCOME_TOTAL                       -0.056650
# AMT_CREDIT                             -0.097990
# AMT_ANNUITY                            -0.019779
#
#                   MIN(bureau.DAYS_ENDDATE_FACT)  SUM(bureau.AMT_ANNUITY)  \
# Variable
# TARGET                                 0.064047                -0.015686
# CNT_CHILDREN                          -0.120403                -0.001963
# AMT_INCOME_TOTAL                      -0.058961                 0.045121
# AMT_CREDIT                            -0.144008                 0.040667
# AMT_ANNUITY                           -0.120252                 0.004213
#
#                   SUM(bureau.AMT_CREDIT_MAX_OVERDUE)  \
# Variable
# TARGET                                     -0.012260
# CNT_CHILDREN                               -0.006078
# AMT_INCOME_TOTAL                            0.049133
# AMT_CREDIT                                  0.011155
# AMT_ANNUITY                                -0.008821
#
#                   SUM(bureau.AMT_CREDIT_SUM)  SUM(bureau.AMT_CREDIT_SUM_DEBT)  \
# Variable
# TARGET                              0.000565                        -0.004916
# CNT_CHILDREN                        0.021041                         0.021949
# AMT_INCOME_TOTAL                    0.069044                         0.049302
# AMT_CREDIT                          0.053785                         0.030732
# AMT_ANNUITY                        -0.005345                        -0.025139
#
#                   SUM(bureau.AMT_CREDIT_SUM_LIMIT)  \
# Variable
# TARGET                                   -0.017827
# CNT_CHILDREN                             -0.023543
# AMT_INCOME_TOTAL                          0.021779
# AMT_CREDIT                                0.051063
# AMT_ANNUITY                               0.000958
#
#                   SUM(bureau.AMT_CREDIT_SUM_OVERDUE)  \
# Variable
# TARGET                                     -0.009344
# CNT_CHILDREN                               -0.013973
# AMT_INCOME_TOTAL                           -0.009561
# AMT_CREDIT                                  0.014029
# AMT_ANNUITY                                -0.000679
#
#                   SUM(bureau.CNT_CREDIT_PROLONG)  \
# Variable
# TARGET                                 -0.015034
# CNT_CHILDREN                            0.048431
# AMT_INCOME_TOTAL                        0.020694
# AMT_CREDIT                              0.008632
# AMT_ANNUITY                            -0.005710
#
#                   SUM(bureau.CREDIT_DAY_OVERDUE)  SUM(bureau.DAYS_CREDIT)  \
# Variable
# TARGET                                 -0.009038                 0.034986
# CNT_CHILDREN                           -0.013516                -0.024109
# AMT_INCOME_TOTAL                       -0.014371                -0.021057
# AMT_CREDIT                              0.000586                -0.042708
# AMT_ANNUITY                            -0.014451                 0.014268
#
#                   SUM(bureau.DAYS_CREDIT_ENDDATE)  \
# Variable
# TARGET                                   0.059098
# CNT_CHILDREN                             0.033921
# AMT_INCOME_TOTAL                         0.028194
# AMT_CREDIT                               0.002111
# AMT_ANNUITY                             -0.019066
#
#                   SUM(bureau.DAYS_CREDIT_UPDATE)  \
# Variable
# TARGET                                  0.033941
# CNT_CHILDREN                           -0.034013
# AMT_INCOME_TOTAL                       -0.010148
# AMT_CREDIT                             -0.035320
# AMT_ANNUITY                             0.013763
#
#                   SUM(bureau.DAYS_ENDDATE_FACT)  COUNT(bureau_balance)  \
# Variable
# TARGET                                 0.039069                    NaN
# CNT_CHILDREN                          -0.030363                    NaN
# AMT_INCOME_TOTAL                      -0.014899                    NaN
# AMT_CREDIT                            -0.038620                    NaN
# AMT_ANNUITY                            0.007961                    NaN
#
#                   MAX(bureau_balance.MONTHS_BALANCE)  \
# Variable
# TARGET                                           NaN
# CNT_CHILDREN                                     NaN
# AMT_INCOME_TOTAL                                 NaN
# AMT_CREDIT                                       NaN
# AMT_ANNUITY                                      NaN
#
#                   MEAN(bureau_balance.MONTHS_BALANCE)  \
# Variable
# TARGET                                            NaN
# CNT_CHILDREN                                      NaN
# AMT_INCOME_TOTAL                                  NaN
# AMT_CREDIT                                        NaN
# AMT_ANNUITY                                       NaN
#
#                   MIN(bureau_balance.MONTHS_BALANCE)  \
# Variable
# TARGET                                           NaN
# CNT_CHILDREN                                     NaN
# AMT_INCOME_TOTAL                                 NaN
# AMT_CREDIT                                       NaN
# AMT_ANNUITY                                      NaN
#
#                   SUM(bureau_balance.MONTHS_BALANCE)  COUNT(previous)  \
# Variable
# TARGET                                           NaN        -0.042367
# CNT_CHILDREN                                     NaN         0.001990
# AMT_INCOME_TOTAL                                 NaN         0.042237
# AMT_CREDIT                                       NaN         0.026876
# AMT_ANNUITY                                      NaN        -0.009379
#
#                   MAX(previous.AMT_ANNUITY)  MAX(previous.AMT_APPLICATION)  \
# Variable
# TARGET                            -0.083913                      -0.064273
# CNT_CHILDREN                       0.091299                       0.097161
# AMT_INCOME_TOTAL                   0.420467                       0.320995
# AMT_CREDIT                         0.293342                       0.208533
# AMT_ANNUITY                        0.297436                       0.188371
#
#                   MAX(previous.AMT_CREDIT)  MAX(previous.AMT_DOWN_PAYMENT)  \
# Variable
# TARGET                           -0.065050                       -0.054121
# CNT_CHILDREN                      0.100607                        0.196333
# AMT_INCOME_TOTAL                  0.311447                        0.073763
# AMT_CREDIT                        0.200794                        0.040263
# AMT_ANNUITY                       0.182475                       -0.000017
#
#                   MAX(previous.AMT_GOODS_PRICE)  MAX(previous.CNT_PAYMENT)  \
# Variable
# TARGET                                -0.065858                  -0.014552
# CNT_CHILDREN                           0.094469                   0.067052
# AMT_INCOME_TOTAL                       0.319888                   0.190358
# AMT_CREDIT                             0.212222                   0.013347
# AMT_ANNUITY                            0.189486                   0.006781
#
#                   MAX(previous.DAYS_DECISION)  \
# Variable
# TARGET                               0.036256
# CNT_CHILDREN                         0.150805
# AMT_INCOME_TOTAL                     0.107062
# AMT_CREDIT                          -0.104998
# AMT_ANNUITY                         -0.065556
#
#                   MAX(previous.DAYS_FIRST_DRAWING)  \
# Variable
# TARGET                                    0.016855
# CNT_CHILDREN                             -0.063945
# AMT_INCOME_TOTAL                          0.028723
# AMT_CREDIT                               -0.019246
# AMT_ANNUITY                               0.026012
#
#                   MAX(previous.DAYS_FIRST_DUE)  MAX(previous.DAYS_LAST_DUE)  \
# Variable
# TARGET                                0.223855                     0.159071
# CNT_CHILDREN                          0.009755                     0.036158
# AMT_INCOME_TOTAL                      0.076404                     0.025491
# AMT_CREDIT                            0.050824                    -0.054221
# AMT_ANNUITY                           0.066798                    -0.054080
#
#                   MAX(previous.DAYS_LAST_DUE_1ST_VERSION)  \
# Variable
# TARGET                                           0.131274
# CNT_CHILDREN                                     0.087453
# AMT_INCOME_TOTAL                                 0.136873
# AMT_CREDIT                                       0.094427
# AMT_ANNUITY                                      0.089343
#
#                   MAX(previous.DAYS_TERMINATION)  \
# Variable
# TARGET                                  0.090196
# CNT_CHILDREN                            0.018247
# AMT_INCOME_TOTAL                       -0.057800
# AMT_CREDIT                             -0.069287
# AMT_ANNUITY                            -0.100829
#
#                   MAX(previous.HOUR_APPR_PROCESS_START)  \
# Variable
# TARGET                                         0.066132
# CNT_CHILDREN                                  -0.037208
# AMT_INCOME_TOTAL                               0.202069
# AMT_CREDIT                                     0.004687
# AMT_ANNUITY                                    0.113747
#
#                   MAX(previous.NFLAG_INSURED_ON_APPROVAL)  \
# Variable
# TARGET                                          -0.050540
# CNT_CHILDREN                                    -0.038898
# AMT_INCOME_TOTAL                                 0.090634
# AMT_CREDIT                                      -0.009871
# AMT_ANNUITY                                      0.025065
#
#                   MAX(previous.NFLAG_LAST_APPL_IN_DAY)  \
# Variable
# TARGET                                             NaN
# CNT_CHILDREN                                       NaN
# AMT_INCOME_TOTAL                                   NaN
# AMT_CREDIT                                         NaN
# AMT_ANNUITY                                        NaN
#
#                   MAX(previous.RATE_DOWN_PAYMENT)  \
# Variable
# TARGET                                   0.001938
# CNT_CHILDREN                             0.129379
# AMT_INCOME_TOTAL                         0.079034
# AMT_CREDIT                              -0.003920
# AMT_ANNUITY                             -0.029181
#
#                   MAX(previous.RATE_INTEREST_PRIMARY)  \
# Variable
# TARGET                                            NaN
# CNT_CHILDREN                                 0.866025
# AMT_INCOME_TOTAL                            -0.866025
# AMT_CREDIT                                  -0.983161
# AMT_ANNUITY                                 -0.980438
#
#                   MAX(previous.RATE_INTEREST_PRIVILEGED)  \
# Variable
# TARGET                                               NaN
# CNT_CHILDREN                                    0.866025
# AMT_INCOME_TOTAL                               -0.866025
# AMT_CREDIT                                     -0.983161
# AMT_ANNUITY                                    -0.980438
#
#                   MAX(previous.SELLERPLACE_AREA)  MEAN(previous.AMT_ANNUITY)  \
# Variable
# TARGET                                 -0.083696                   -0.062644
# CNT_CHILDREN                            0.020780                    0.064036
# AMT_INCOME_TOTAL                        0.134694                    0.361530
# AMT_CREDIT                              0.084039                    0.320776
# AMT_ANNUITY                             0.125546                    0.323405
#
#                   MEAN(previous.AMT_APPLICATION)  MEAN(previous.AMT_CREDIT)  \
# Variable
# TARGET                                 -0.062473                  -0.045140
# CNT_CHILDREN                            0.097210                   0.081954
# AMT_INCOME_TOTAL                        0.198462                   0.213783
# AMT_CREDIT                              0.210472                   0.220113
# AMT_ANNUITY                             0.174824                   0.184203
#
#                   MEAN(previous.AMT_DOWN_PAYMENT)  \
# Variable
# TARGET                                  -0.065085
# CNT_CHILDREN                             0.161067
# AMT_INCOME_TOTAL                         0.045284
# AMT_CREDIT                               0.010634
# AMT_ANNUITY                             -0.020597
#
#                   MEAN(previous.AMT_GOODS_PRICE)  MEAN(previous.CNT_PAYMENT)  \
# Variable
# TARGET                                 -0.071223                   -0.000605
# CNT_CHILDREN                            0.071241                   -0.021242
# AMT_INCOME_TOTAL                        0.254173                    0.081507
# AMT_CREDIT                              0.216567                   -0.008902
# AMT_ANNUITY                             0.204561                   -0.034106
#
#                   MEAN(previous.DAYS_DECISION)  \
# Variable
# TARGET                                0.076998
# CNT_CHILDREN                          0.062882
# AMT_INCOME_TOTAL                      0.017954
# AMT_CREDIT                           -0.173988
# AMT_ANNUITY                          -0.105467
#
#                   MEAN(previous.DAYS_FIRST_DRAWING)  \
# Variable
# TARGET                                     0.028221
# CNT_CHILDREN                              -0.060237
# AMT_INCOME_TOTAL                          -0.066423
# AMT_CREDIT                                -0.069091
# AMT_ANNUITY                               -0.044295
#
#                   MEAN(previous.DAYS_FIRST_DUE)  MEAN(previous.DAYS_LAST_DUE)  \
# Variable
# TARGET                                 0.282470                      0.133922
# CNT_CHILDREN                          -0.004020                     -0.038258
# AMT_INCOME_TOTAL                       0.094925                     -0.061914
# AMT_CREDIT                             0.054810                     -0.140302
# AMT_ANNUITY                            0.097472                     -0.101801
#
#                   MEAN(previous.DAYS_LAST_DUE_1ST_VERSION)  \
# Variable
# TARGET                                            0.073209
# CNT_CHILDREN                                      0.028156
# AMT_INCOME_TOTAL                                  0.072133
# AMT_CREDIT                                        0.108478
# AMT_ANNUITY                                       0.096774
#
#                   MEAN(previous.DAYS_TERMINATION)  \
# Variable
# TARGET                                   0.087916
# CNT_CHILDREN                            -0.028394
# AMT_INCOME_TOTAL                        -0.097641
# AMT_CREDIT                              -0.135409
# ...
# Variable
# TARGET                                    0.132085
# CNT_CHILDREN                              0.071823
# AMT_INCOME_TOTAL                         -0.184665
# AMT_CREDIT                               -0.054141
# AMT_ANNUITY                              -0.140541
#
#                   MIN(credit.previous.AMT_APPLICATION)  \
# Variable
# TARGET                                       -0.259272
# CNT_CHILDREN                                 -0.358842
# AMT_INCOME_TOTAL                             -0.011766
# AMT_CREDIT                                   -0.264310
# AMT_ANNUITY                                   0.001374
#
#                   MIN(credit.previous.AMT_CREDIT)  \
# Variable
# TARGET                                   0.132085
# CNT_CHILDREN                             0.071823
# AMT_INCOME_TOTAL                        -0.184665
# AMT_CREDIT                              -0.054141
# AMT_ANNUITY                             -0.140541
#
#                   MIN(credit.previous.AMT_DOWN_PAYMENT)  \
# Variable
# TARGET                                              NaN
# CNT_CHILDREN                                        NaN
# AMT_INCOME_TOTAL                                    NaN
# AMT_CREDIT                                          NaN
# AMT_ANNUITY                                         NaN
#
#                   MIN(credit.previous.AMT_GOODS_PRICE)  \
# Variable
# TARGET                                             NaN
# CNT_CHILDREN                                 -0.329622
# AMT_INCOME_TOTAL                             -0.162957
# AMT_CREDIT                                   -0.368177
# AMT_ANNUITY                                  -0.146928
#
#                   MIN(credit.previous.CNT_PAYMENT)  \
# Variable
# TARGET                                         NaN
# CNT_CHILDREN                                   NaN
# AMT_INCOME_TOTAL                               NaN
# AMT_CREDIT                                     NaN
# AMT_ANNUITY                                    NaN
#
#                   MIN(credit.previous.DAYS_DECISION)  \
# Variable
# TARGET                                      0.072940
# CNT_CHILDREN                               -0.426542
# AMT_INCOME_TOTAL                           -0.037912
# AMT_CREDIT                                 -0.180962
# AMT_ANNUITY                                -0.037783
#
#                   MIN(credit.previous.DAYS_FIRST_DRAWING)  \
# Variable
# TARGET                                           0.001186
# CNT_CHILDREN                                    -0.291846
# AMT_INCOME_TOTAL                                -0.023010
# AMT_CREDIT                                       0.032215
# AMT_ANNUITY                                      0.138735
#
#                   MIN(credit.previous.DAYS_FIRST_DUE)  \
# Variable
# TARGET                                       0.001188
# CNT_CHILDREN                                -0.291843
# AMT_INCOME_TOTAL                            -0.023012
# AMT_CREDIT                                   0.032211
# AMT_ANNUITY                                  0.138728
#
#                   MIN(credit.previous.DAYS_LAST_DUE)  \
# Variable
# TARGET                                      0.219264
# CNT_CHILDREN                               -0.396341
# AMT_INCOME_TOTAL                           -0.008415
# AMT_CREDIT                                 -0.188291
# AMT_ANNUITY                                -0.116647
#
#                   MIN(credit.previous.DAYS_LAST_DUE_1ST_VERSION)  \
# Variable
# TARGET                                                       NaN
# CNT_CHILDREN                                                 NaN
# AMT_INCOME_TOTAL                                             NaN
# AMT_CREDIT                                                   NaN
# AMT_ANNUITY                                                  NaN
#
#                   MIN(credit.previous.DAYS_TERMINATION)  \
# Variable
# TARGET                                         0.158114
# CNT_CHILDREN                                   0.011537
# AMT_INCOME_TOTAL                              -0.221257
# AMT_CREDIT                                     0.085355
# AMT_ANNUITY                                   -0.117605
#
#                   MIN(credit.previous.HOUR_APPR_PROCESS_START)  \
# Variable
# TARGET                                               -0.102774
# CNT_CHILDREN                                         -0.099195
# AMT_INCOME_TOTAL                                      0.126496
# AMT_CREDIT                                           -0.444454
# AMT_ANNUITY                                          -0.365997
#
#                   MIN(credit.previous.NFLAG_INSURED_ON_APPROVAL)  \
# Variable
# TARGET                                                       NaN
# CNT_CHILDREN                                                 NaN
# AMT_INCOME_TOTAL                                             NaN
# AMT_CREDIT                                                   NaN
# AMT_ANNUITY                                                  NaN
#
#                   MIN(credit.previous.NFLAG_LAST_APPL_IN_DAY)  \
# Variable
# TARGET                                                    NaN
# CNT_CHILDREN                                              NaN
# AMT_INCOME_TOTAL                                          NaN
# AMT_CREDIT                                                NaN
# AMT_ANNUITY                                               NaN
#
#                   MIN(credit.previous.RATE_DOWN_PAYMENT)  \
# Variable
# TARGET                                               NaN
# CNT_CHILDREN                                         NaN
# AMT_INCOME_TOTAL                                     NaN
# AMT_CREDIT                                           NaN
# AMT_ANNUITY                                          NaN
#
#                   MIN(credit.previous.RATE_INTEREST_PRIMARY)  \
# Variable
# TARGET                                                   NaN
# CNT_CHILDREN                                             NaN
# AMT_INCOME_TOTAL                                         NaN
# AMT_CREDIT                                               NaN
# AMT_ANNUITY                                              NaN
#
#                   MIN(credit.previous.RATE_INTEREST_PRIVILEGED)  \
# Variable
# TARGET                                                      NaN
# CNT_CHILDREN                                                NaN
# AMT_INCOME_TOTAL                                            NaN
# AMT_CREDIT                                                  NaN
# AMT_ANNUITY                                                 NaN
#
#                   MIN(credit.previous.SELLERPLACE_AREA)  \
# Variable
# TARGET                                        -0.086125
# CNT_CHILDREN                                  -0.140141
# AMT_INCOME_TOTAL                              -0.154276
# AMT_CREDIT                                    -0.049263
# AMT_ANNUITY                                   -0.031129
#
#                   SUM(credit.previous.AMT_ANNUITY)  \
# Variable
# TARGET                                    0.036121
# CNT_CHILDREN                              0.038938
# AMT_INCOME_TOTAL                          0.011763
# AMT_CREDIT                                0.033207
# AMT_ANNUITY                              -0.003731
#
#                   SUM(credit.previous.AMT_APPLICATION)  \
# Variable
# TARGET                                       -0.017869
# CNT_CHILDREN                                 -0.024019
# AMT_INCOME_TOTAL                              0.014796
# AMT_CREDIT                                   -0.010364
# AMT_ANNUITY                                  -0.004641
#
#                   SUM(credit.previous.AMT_CREDIT)  \
# Variable
# TARGET                                   0.036121
# CNT_CHILDREN                             0.038938
# AMT_INCOME_TOTAL                         0.011763
# AMT_CREDIT                               0.033207
# AMT_ANNUITY                             -0.003731
#
#                   SUM(credit.previous.AMT_DOWN_PAYMENT)  \
# Variable
# TARGET                                              NaN
# CNT_CHILDREN                                        NaN
# AMT_INCOME_TOTAL                                    NaN
# AMT_CREDIT                                          NaN
# AMT_ANNUITY                                         NaN
#
#                   SUM(credit.previous.AMT_GOODS_PRICE)  \
# Variable
# TARGET                                       -0.017869
# CNT_CHILDREN                                 -0.024019
# AMT_INCOME_TOTAL                              0.014796
# AMT_CREDIT                                   -0.010364
# AMT_ANNUITY                                  -0.004641
#
#                   SUM(credit.previous.CNT_PAYMENT)  \
# Variable
# TARGET                                         NaN
# CNT_CHILDREN                                   NaN
# AMT_INCOME_TOTAL                               NaN
# AMT_CREDIT                                     NaN
# AMT_ANNUITY                                    NaN
#
#                   SUM(credit.previous.DAYS_DECISION)  \
# Variable
# TARGET                                      0.007119
# CNT_CHILDREN                               -0.049558
# AMT_INCOME_TOTAL                           -0.013829
# AMT_CREDIT                                 -0.019992
# AMT_ANNUITY                                 0.005133
#
#                   SUM(credit.previous.DAYS_FIRST_DRAWING)  \
# Variable
# TARGET                                           0.066326
# CNT_CHILDREN                                    -0.019888
# AMT_INCOME_TOTAL                                 0.004167
# AMT_CREDIT                                       0.012280
# AMT_ANNUITY                                     -0.005743
#
#                   SUM(credit.previous.DAYS_FIRST_DUE)  \
# Variable
# TARGET                                       0.066322
# CNT_CHILDREN                                -0.019865
# AMT_INCOME_TOTAL                             0.004174
# AMT_CREDIT                                   0.012287
# AMT_ANNUITY                                 -0.005749
#
#                   SUM(credit.previous.DAYS_LAST_DUE)  \
# Variable
# TARGET                                      0.070018
# CNT_CHILDREN                                0.014447
# AMT_INCOME_TOTAL                            0.016743
# AMT_CREDIT                                  0.004042
# AMT_ANNUITY                                -0.019086
#
#                   SUM(credit.previous.DAYS_LAST_DUE_1ST_VERSION)  \
# Variable
# TARGET                                                  0.006388
# CNT_CHILDREN                                            0.045447
# AMT_INCOME_TOTAL                                        0.017670
# AMT_CREDIT                                              0.024647
# AMT_ANNUITY                                            -0.006014
#
#                   SUM(credit.previous.DAYS_TERMINATION)  \
# Variable
# TARGET                                         0.008037
# CNT_CHILDREN                                   0.049537
# AMT_INCOME_TOTAL                               0.014128
# AMT_CREDIT                                     0.028741
# AMT_ANNUITY                                   -0.005005
#
#                   SUM(credit.previous.HOUR_APPR_PROCESS_START)  \
# Variable
# TARGET                                                0.007528
# CNT_CHILDREN                                          0.044901
# AMT_INCOME_TOTAL                                      0.017574
# AMT_CREDIT                                            0.012893
# AMT_ANNUITY                                          -0.012305
#
#                   SUM(credit.previous.NFLAG_INSURED_ON_APPROVAL)  \
# Variable
# TARGET                                                       NaN
# CNT_CHILDREN                                                 NaN
# AMT_INCOME_TOTAL                                             NaN
# AMT_CREDIT                                                   NaN
# AMT_ANNUITY                                                  NaN
#
#                   SUM(credit.previous.NFLAG_LAST_APPL_IN_DAY)  \
# Variable
# TARGET                                               0.006388
# CNT_CHILDREN                                         0.045447
# AMT_INCOME_TOTAL                                     0.017670
# AMT_CREDIT                                           0.024647
# AMT_ANNUITY                                         -0.006014
#
#                   SUM(credit.previous.RATE_DOWN_PAYMENT)  \
# Variable
# TARGET                                               NaN
# CNT_CHILDREN                                         NaN
# AMT_INCOME_TOTAL                                     NaN
# AMT_CREDIT                                           NaN
# AMT_ANNUITY                                          NaN
#
#                   SUM(credit.previous.RATE_INTEREST_PRIMARY)  \
# Variable
# TARGET                                                   NaN
# CNT_CHILDREN                                             NaN
# AMT_INCOME_TOTAL                                         NaN
# AMT_CREDIT                                               NaN
# AMT_ANNUITY                                              NaN
#
#                   SUM(credit.previous.RATE_INTEREST_PRIVILEGED)  \
# Variable
# TARGET                                                      NaN
# CNT_CHILDREN                                                NaN
# AMT_INCOME_TOTAL                                            NaN
# AMT_CREDIT                                                  NaN
# AMT_ANNUITY                                                 NaN
#
#                   SUM(credit.previous.SELLERPLACE_AREA)
# Variable
# TARGET                                        -0.008868
# CNT_CHILDREN                                  -0.012125
# AMT_INCOME_TOTAL                              -0.014039
# AMT_CREDIT                                    -0.002525
# AMT_ANNUITY                                   -0.004975
#
# [5 rows x 1118 columns]
